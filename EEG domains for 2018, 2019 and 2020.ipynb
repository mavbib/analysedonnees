# %%
import re 
import metaknowledge as mk
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import nltk as nltk
import scipy.sparse as sparse
from wordcloud import WordCloud
from stop_words import get_stop_words
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import MWETokenizer
from nltk.stem import WordNetLemmatizer
from numpy import array
from numpy import count_nonzero
import csv

# %% [markdown]
# <h3>1. First Step: getting the files with the data.</h3><p>Following the imports for the project. We have to download the data from  <a href="https://pubmed.ncbi.nlm.nih.gov/" target="_blank">Pubmed</a>. We make a request with the term 'EEG' and filter on one year. We download the file with 'Send to' 'Citation manager' for each year. We shall have (as for the 5th of April 2021):<p>
# <ul><li>2018 we shall have 8,097 notices.</li><li>For 2019 should be 8,160 notices</li><li>2020 we shall have 7661 notices</li></ul></br>
# <p>These notices shall be in a .nbib format.</p>

# %% [markdown]
# <h3>2. Getting each file in a record collection</h3><p>Using metaknowledge Python library. We ought load the files in a record collection. One collection for each year. We want to compare each year in a TF-IDF matrix to do so each year would be a document therefor each year would be a row in the matrix.<p>

# %%
RC2020 = mk.RecordCollection("pubmed-eeg-set2020.nbib")

# %%
RC2019 = mk.RecordCollection("pubmed-eeg-set2019.nbib")

# %%
RC2018 = mk.RecordCollection("pubmed-eeg-set2018.nbib")

# %% [markdown]
# <h3>3. Extract MeSH Terms</h3>
# <p>We know that Pubmed use abbreviation to identify data field (<a href="https://www.nlm.nih.gov/bsd/mms/medlineelements.html#:~:text=MEDLINE%20%C2%AE%20%2FPubMed%20%C2%AE%20Data%20Element%20%28Field%29%20Descriptions,%20%20%28LA%29%20%2018%20more%20rows%20" target="_blank">MEDLINE®/PubMed® Data Element (Field) Descriptions</a>). We have seen in the first test that these abbreviations are use as column's title in the .nbib files. So in order not to make this Notebook file loud we will skip the conversion of our records to dataframes only to have a look at the data. It has been done in previous phase of the project.</p><p>We would create a variable for the MeSH column as a list. The column containing the MeSH terms have an MH abbreviation.</p>

# %%
selectionMesh = ['MH']

# %% [markdown]
# <h3>3.1 Extract MeSH Terms as Dataframe</h3>
# <p>Next we would create a dataframe in the form of Python dictionnary. We will use an index as keys and the MeSH terms as values.</p>

# %%
noticesMesh2020 = pd.DataFrame(RC2020.makeDict(onlyTheseTags=selectionMesh, genderCounts=False, numAuthors=False))

# %%
noticesMesh2019 = pd.DataFrame(RC2019.makeDict(onlyTheseTags = selectionMesh, genderCounts = False, numAuthors = False))

# %%
noticesMesh2018 = pd.DataFrame(RC2018.makeDict(onlyTheseTags = selectionMesh, genderCounts = False, numAuthors = False))

# %%
noticesMesh2018
# Out:
#                                                      MH
# 0     [Adult, Brain Waves/physiology, Chorea/*etiolo...
# 1     [Aged, Brain/physiopathology, Electroencephalo...
# 2     [Adult, Anticipation, Psychological/*physiolog...
# 3     [Brain/*pathology, Canada, *Electroencephalogr...
# 4     [*Body Image, Brain Mapping, Cerebral Cortex/d...
# ...                                                 ...
# 8092  [Adult, Anticipation, Psychological/*physiolog...
# 8093  [Adolescent, Brain/diagnostic imaging/*physiop...
# 8094  [Algorithms, Alzheimer Disease/*diagnosis, Bay...
# 8095                                               None
# 8096  [Acute Disease, Adolescent, Adult, Affect/*phy...
#
# [8097 rows x 1 columns]

# %% [markdown]
# <h3>4. Delete empty rows</h3>
# <p>We use dropna() method on each dataframe. Notices with no MeSH terms won't be useful.</p>

# %%
noticesMesh2018 = noticesMesh2018.dropna()

# %%
noticesMesh2019 = noticesMesh2019.dropna()

# %%
noticesMesh2020 = noticesMesh2020.dropna()

# %% [markdown]
# <h3>5. Clean the Data.</h3>
# <p>We tried many approaches. We don't claim that the one we selected is the best. We selected this one because we had more accurate results than the other approaches that we tried in a format that we were able to convert in a TF-IDF matrix. We shall create csv files for each year and load these csv files to join our data into a Python string.</p>

# %%
noticesMesh2018.to_csv("meshDrop2018.csv", index=False, header=False)

# %%
noticesMesh2019.to_csv("meshDrop2019.csv", index=False, header=False)

# %%
noticesMesh2020.to_csv("meshDrop2020.csv", index=False, header=False)

# %%
mesh2018 = []
with open('meshDrop2018.csv', 'r')as f:
    reader = csv.reader(f)
    mesh2018 = ' '.join([i[0] for i in reader])

# %%
mesh2019 = []
with open('meshDrop2019.csv', 'r')as f:
    reader = csv.reader(f)
    mesh2019 = ' '.join([i[0] for i in reader])

# %%
mesh2020 = []
with open('meshDrop2020.csv', 'r')as f:
    reader = csv.reader(f)
    mesh2020 = ' '.join([i[0] for i in reader])

# %% [markdown]
# <h3>5.1 Clean the Data : the Replacement</h3>
# <p>Some characters are not needed such as '*' and '\'. We'll replace them with blank '' using replace method.</p>

# %%
mesh2018 = mesh2018.replace('*','')

# %%
mesh2018 = mesh2018.replace("\'","")

# %%
mesh2019 = mesh2019.replace('*','')

# %%
mesh2019 = mesh2019.replace("\'","")

# %%
mesh2020 = mesh2020.replace('*','')

# %%
mesh2020 = mesh2020.replace("\'","")

# %% [markdown]
# <h3>5.3 Clean the Data: Stop Words</h3>
# <p>We shall remove common generic words from our MeSH terms data. We will the standard stop_words for English in the NLTK library. We will add to this list MeSH terms concerning 'subject' or 'participants' of articles rather than topics. MeSH terms such as Humans, Adult, Students, etc. Since we're looking for fields in witch EEG method is used. The MeSH terms representing the 'subject' or 'participants' of a study or experiment are not of interest for our question. </p><p>There are animals MeSH terms as well. For human related participant in MeSH terms. The whole list of terms appear in the <a href="https://meshb.nlm.nih.gov/treeView" target="_blank">MeSH Browser thesaurus</a> under the MeSH term 'person'. MeSH terms related to animals are not grouped in one place. We may take a few into account like 'mice' and 'rat' but we don't know if it's complete or not.</p>
# <p>On a similar concern: there are MeSH terms representing products, drugs or chemicals and the like such as GABA here and there. Idealy they should be remove from our datasets. Here we are limited by our own knowledge of the EEG method. We don't know these products.</p>

# %%
listMeshPart = ['Adult', 'Child', 'Men', 'Women', 'Students', 'Humans', 'Male', 'Female', 'Athletes', 'Adolescent', 'Infant', 'Aged', 'Middle Aged', 'Young Adult', 'Animals', 'Mice', 'parent', 'Young', 'Rat', 'Electroencephalography','Electroencephalography/methods', 'Method', 'imaging', 'potential','diagnosis','diagnostic','Evoked', 'drug']

# %%
stop_words = set(stopwords.words('english'))
MeshSub2018 = stop_words.union(listMeshPart)
word_tokens = word_tokenize(mesh2018)

filtSent2018 = [] 

for w in word_tokens:  
    if w not in MeshSub2018:  
        filtSent2018.append(w)

# %%
stop_words = set(stopwords.words('english'))
MeshSub2019 = stop_words.union(listMeshPart)
word_tokens = word_tokenize(mesh2019)

filtSent2019 = [] 

for w in word_tokens:  
    if w not in MeshSub2019:  
        filtSent2019.append(w)

# %%
stop_words = set(stopwords.words('english'))
MeshSub2020 = stop_words.union(listMeshPart)
word_tokens = word_tokenize(mesh2020)

filtSent2020 = [] 

for w in word_tokens:  
    if w not in MeshSub2020:  
        filtSent2020.append(w)

# %%
MeshSub2018
# Out:
# {'Adolescent',
#  'Adult',
#  'Aged',
#  'Animals',
#  'Athletes',
#  'Child',
#  'Electroencephalography',
#  'Electroencephalography/methods',
#  'Evoked',
#  'Female',
#  'Humans',
#  'Infant',
#  'Male',
#  'Men',
#  'Method',
#  'Mice',
#  'Middle Aged',
#  'Rat',
#  'Students',
#  'Women',
#  'Young',
#  'Young Adult',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'diagnosis',
#  'diagnostic',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'drug',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'imaging',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'parent',
#  'potential',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filtSent2018
# Out:
# ['[',
#  ',',
#  'Brain',
#  'Waves/physiology',
#  ',',
#  'Chorea/etiology',
#  ',',
#  ',',
#  'Epilepsy/complications',
#  ',',
#  ',',
#  ']',
#  '[',
#  ',',
#  'Brain/physiopathology',
#  ',',
#  ',',
#  'Encephalitis/complications/drug',
#  'therapy/immunology',
#  ',',
#  'Glucocorticoids/therapeutic',
#  'use',
#  ',',
#  ',',
#  'Intracellular',
#  'Signaling',
#  'Peptides',
#  'Proteins',
#  ',',
#  ',',
#  'Methylprednisolone/therapeutic',
#  'use',
#  ',',
#  'Proteins/immunology',
#  ',',
#  'Seizures/complications/drug',
#  'therapy/immunology',
#  ']',
#  '[',
#  ',',
#  'Anticipation',
#  ',',
#  'Psychological/physiology',
#  ',',
#  'Auditory',
#  'Perception/physiology',
#  ',',
#  'Cues',
#  ',',
#  ',',
#  'Potentials/physiology',
#  ',',
#  'Feedback',
#  ',',
#  'Psychological/physiology',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Psychomotor',
#  'Performance/physiology',
#  ',',
#  'Reward',
#  ',',
#  'Visual',
#  'Perception/physiology',
#  ',',
#  ']',
#  '[',
#  'Brain/pathology',
#  ',',
#  'Canada',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Hypothermia',
#  ',',
#  'Induced/methods',
#  ',',
#  'Hypoxia-Ischemia',
#  ',',
#  'Brain/diagnosis',
#  ',',
#  ',',
#  'Newborn',
#  ',',
#  'Magnetic',
#  'Resonance',
#  'Imaging',
#  ',',
#  ',',
#  'Neurologic',
#  'Examination',
#  ',',
#  'Predictive',
#  'Value',
#  'Tests',
#  ',',
#  'Prospective',
#  'Studies',
#  ',',
#  'Seizures/diagnosis/etiology',
#  ',',
#  'Severity',
#  'Illness',
#  'Index',
#  ']',
#  '[',
#  'Body',
#  'Image',
#  ',',
#  'Brain',
#  'Mapping',
#  ',',
#  'Cerebral',
#  'Cortex/diagnostic',
#  'imaging/physiology/physiopathology',
#  ',',
#  'Drug',
#  'Resistant',
#  'Epilepsy/diagnostic',
#  'imaging/physiopathology',
#  ',',
#  'Electric',
#  'Stimulation',
#  ',',
#  'Electrocorticography',
#  ',',
#  ',',
#  ',',
#  'Implantable',
#  'Neurostimulators',
#  ',',
#  ',',
#  'Visual',
#  'Perception/physiology',
#  ',',
#  ']',
#  '[',
#  ',',
#  ',',
#  '80',
#  ',',
#  'Alpha',
#  'Rhythm/physiology',
#  ',',
#  'Alzheimer',
#  'Disease/diagnosis/physiopathology',
#  ',',
#  'Blinking/physiology',
#  ',',
#  'Cerebral',
#  'Cortex/physiopathology',
#  ',',
#  'Cortical',
#  'Synchronization/physiology',
#  ',',
#  ',',
#  ',',
#  'Lewy',
#  'Body',
#  'Disease/diagnosis/physiopathology',
#  ',',
#  'Magnetoencephalography/methods',
#  ',',
#  ',',
#  'Ocular',
#  'Physiological',
#  'Phenomena',
#  ',',
#  'Visual',
#  'Perception/physiology',
#  ']',
#  '[',
#  'Anesthesia',
#  ',',
#  'General/methods/statistics',
#  '&',
#  'numerical',
#  'data',
#  ',',
#  'Electroencephalography/methods/statistics',
#  '&',
#  'numerical',
#  'data',
#  ',',
#  ',',
#  'Models',
#  ',',
#  'Theoretical',
#  ',',
#  'Stochastic',
#  'Processes',
#  ']',
#  '[',
#  ',',
#  ',',
#  'Laboratory',
#  ',',
#  'Biomarkers/metabolism',
#  ',',
#  'Drug',
#  'Evaluation',
#  ',',
#  'Preclinical/methods',
#  ',',
#  'Drug-Related',
#  'Side',
#  'Effects',
#  'Adverse',
#  'Reactions/diagnosis/metabolism',
#  ',',
#  ',',
#  ',',
#  'Pharmaceutical',
#  'Preparations/administration',
#  '&',
#  'dosage',
#  ',',
#  'Risk',
#  'Assessment',
#  ',',
#  'Safety',
#  ',',
#  'Seizures/chemically',
#  'induced/diagnosis/metabolism',
#  ',',
#  'Telemetry/methods',
#  ']',
#  '[',
#  ',',
#  'Anxiety/diagnosis/psychology',
#  ',',
#  'Attention/physiology',
#  ',',
#  'Cues',
#  ',',
#  'Disgust',
#  ',',
#  'Drug',
#  'Labeling/legislation',
#  '&',
#  'jurisprudence/standards',
#  ',',
#  'Electroencephalography/methods/psychology',
#  ',',
#  'Event-Related',
#  'Potentials',
#  ',',
#  'P300/physiology',
#  ',',
#  'Fear/physiology/psychology',
#  ',',
#  ',',
#  'Health',
#  'Risk',
#  'Behaviors/physiology',
#  ',',
#  ',',
#  ',',
#  'Motivation/physiology',
#  ',',
#  'Photic',
#  'Stimulation/methods',
#  ',',
#  'Smokers/psychology',
#  ',',
#  'Tobacco',
#  'Products/legislation',
#  '&',
#  'jurisprudence/standards',
#  ']',
#  '[',
#  ',',
#  ',',
#  ',',
#  '80',
#  ',',
#  'Bayes',
#  'Theorem',
#  ',',
#  'Case-Control',
#  'Studies',
#  ',',
#  ',',
#  'Electromyography',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Middle',
#  ',',
#  'Motor',
#  'Cortex/physiology',
#  ',',
#  'Neural',
#  'Pathways/physiology',
#  ',',
#  'Parietal',
#  'Lobe/physiology',
#  ',',
#  'Stroke/physiopathology',
#  ']',
#  '[',
#  ',',
#  'Association',
#  'Learning/physiology',
#  ',',
#  'Attention/physiology',
#  ',',
#  'Cues',
#  ',',
#  'Eye',
#  'Movement',
#  'Measurements',
#  ',',
#  ',',
#  'Pattern',
#  'Recognition',
#  ',',
#  'Visual/physiology',
#  ',',
#  'Psychomotor',
#  'Performance/physiology',
#  ',',
#  'Uncertainty',
#  ',',
#  ']',
#  '[',
#  ',',
#  'Brain',
#  'Stem/physiology',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Judgment/physiology',
#  ',',
#  'Language',
#  ',',
#  ',',
#  'Models',
#  ',',
#  'Psychological',
#  ',',
#  'Pitch',
#  'Perception/physiology',
#  ',',
#  'Speech',
#  'Perception/physiology',
#  ']',
#  '[',
#  'Brain/diagnostic',
#  'imaging/physiopathology',
#  ',',
#  'Electroencephalography/classification',
#  ',',
#  'Epilepsy/classification/diagnosis/physiopathology/therapy',
#  ',',
#  'Functional',
#  'Laterality',
#  ',',
#  ',',
#  'Periodicity',
#  ',',
#  'Terminology',
#  'Topic',
#  ']',
#  '[',
#  ',',
#  ',',
#  'Potentials/physiology',
#  ',',
#  ',',
#  'Functional',
#  'Laterality/physiology',
#  ',',
#  ',',
#  ',',
#  'Memory',
#  ',',
#  'Episodic',
#  ',',
#  'Mental',
#  'Recall/physiology',
#  ',',
#  'Recognition',
#  ',',
#  'Psychology/physiology',
#  ',',
#  'Visual',
#  'Fields/physiology',
#  ',',
#  'Visual',
#  'Perception/physiology',
#  ',',
#  ']',
#  '[',
#  'Arrhythmias',
#  ',',
#  'Cardiac/physiopathology',
#  ',',
#  'Electrocardiography',
#  ',',
#  'Epilepsy/diagnosis',
#  ',',
#  'Heart',
#  'Rate/physiology',
#  ',',
#  ',',
#  'Predictive',
#  'Value',
#  'Tests',
#  ',',
#  'Seizures/diagnosis',
#  ']',
#  '[',
#  'Algorithms',
#  ',',
#  ',',
#  'Emotions/physiology',
#  ',',
#  'Entropy',
#  ',',
#  ',',
#  'Image',
#  'Processing',
#  ',',
#  'Computer-Assisted/methods',
#  ',',
#  'Time',
#  'Factors',
#  ']',
#  '[',
#  ',',
#  'Eye',
#  'Movement',
#  'Measurements/instrumentation/standards',
#  ',',
#  ',',
#  ',',
#  'Individuality',
#  ',',
#  'Pupil/physiology',
#  ']',
#  '[',
#  ',',
#  'Brain/pathology/physiopathology',
#  ',',
#  'Diffusion',
#  'Tensor',
#  'Imaging',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Inbred',
#  'C57BL',
#  ',',
#  'Rats',
#  ',',
#  'Rats',
#  ',',
#  'Sprague-Dawley',
#  ',',
#  'Status',
#  'Epilepticus/pathology/physiopathology',
#  ']',
#  '[',
#  ',',
#  'Alpha',
#  'Rhythm/physiology',
#  ',',
#  'Cerebral',
#  'Cortex/physiology',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Mathematical',
#  'Concepts',
#  ',',
#  'Nerve',
#  'Net/physiology',
#  ',',
#  'Theta',
#  'Rhythm/physiology',
#  ',',
#  'Thinking/physiology',
#  ',',
#  ']',
#  '[',
#  ',',
#  'Electromyography',
#  ',',
#  ',',
#  'Isometric',
#  'Contraction/physiology',
#  ',',
#  ',',
#  'Motor',
#  'Neurons/physiology',
#  ',',
#  'Movement/physiology',
#  ',',
#  'Psychomotor',
#  'Performance/physiology',
#  ',',
#  'Torque',
#  ',',
#  ']',
#  '[',
#  ',',
#  ',',
#  'Age',
#  'Distribution',
#  ',',
#  'Angelman',
#  'Syndrome/complications/physiopathology',
#  ',',
#  'Anticonvulsants/therapeutic',
#  'use',
#  ',',
#  ',',
#  ',',
#  'Preschool',
#  ',',
#  ',',
#  'Epilepsies',
#  ',',
#  'Myoclonic/drug',
#  'therapy/epidemiology/physiopathology',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Prevalence',
#  ',',
#  'Quality',
#  'Life',
#  ',',
#  'Retrospective',
#  'Studies',
#  ',',
#  'Seizures/drug',
#  'therapy/epidemiology',
#  ',',
#  'Sleep',
#  'Wake',
#  'Disorders',
#  ',',
#  ']',
#  '[',
#  'Anesthesia/methods',
#  ',',
#  ',',
#  'Entropy',
#  ',',
#  ',',
#  'Monitoring',
#  ',',
#  'Intraoperative/methods',
#  ',',
#  'Signal',
#  'Processing',
#  ',',
#  'Computer-Assisted',
#  ',',
#  'Support',
#  'Vector',
#  'Machine',
#  ']',
#  '[',
#  ',',
#  'Attention/physiology',
#  ',',
#  'Awareness/physiology',
#  ',',
#  'Cerebral',
#  'Cortex/physiology',
#  ',',
#  'Consciousness/physiology',
#  ',',
#  'Cues',
#  ',',
#  ',',
#  'Eye',
#  'Movements/physiology',
#  ',',
#  ',',
#  'Models',
#  ',',
#  'Psychological',
#  ',',
#  'Space',
#  'Perception/physiology',
#  ',',
#  'Visual',
#  'Perception/physiology',
#  ']',
#  '[',
#  ',',
#  'Anticonvulsants/administration',
#  '&',
#  'dosage',
#  ',',
#  'Aphasia/etiology',
#  ',',
#  'Cerebral',
#  'Cortex/diagnostic',
#  'imaging/pathology',
#  ',',
#  ',',
#  'Epilepsy/complications/diagnosis/drug',
#  'therapy',
#  ',',
#  ',',
#  ',',
#  'Levetiracetam',
#  ',',
#  'Magnetic',
#  'Resonance',
#  'Angiography',
#  ',',
#  'Piracetam/administration',
#  '&',
#  'dosage/analogs',
#  '&',
#  'derivatives',
#  ']',
#  '[',
#  ',',
#  'Brain',
#  'Injuries/complications/physiopathology',
#  ',',
#  'Electrocorticography/methods',
#  ',',
#  ',',
#  'Epilepsy/etiology/physiopathology',
#  ',',
#  ',',
#  'Nonlinear',
#  'Dynamics',
#  ',',
#  'Rats',
#  ',',
#  'Signal',
#  'Processing',
#  ',',
#  'Computer-Assisted',
#  ']',
#  '[',
#  ',',
#  'Brain/physiology',
#  ',',
#  ',',
#  'Emotions/physiology',
#  ',',
#  'Potentials/physiology',
#  ',',
#  'Facial',
#  'Expression',
#  ',',
#  'Facial',
#  'Recognition/physiology',
#  ',',
#  ',',
#  'Magnetic',
#  'Resonance',
#  'Imaging',
#  ',',
#  ',',
#  'Photic',
#  'Stimulation',
#  ',',
#  'United',
#  'States',
#  ',',
#  'Veterans',
#  ',',
#  ']',
#  '[',
#  'Acoustic',
#  'Stimulation',
#  ',',
#  ',',
#  'Analysis',
#  'Variance',
#  ',',
#  'Auditory',
#  'Perception/physiology',
#  ',',
#  'Brain',
#  'Mapping',
#  ',',
#  ',',
#  'Potentials/physiology',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Music',
#  ',',
#  'Photic',
#  'Stimulation',
#  ',',
#  'Pitch',
#  'Perception/physiology',
#  ',',
#  'Reaction',
#  'Time/physiology',
#  ',',
#  'Spatial',
#  'Processing/physiology',
#  ',',
#  ']',
#  '[',
#  ',',
#  ',',
#  ',',
#  'Preschool',
#  ',',
#  'Cohort',
#  'Studies',
#  ',',
#  'Databases',
#  ',',
#  'Factual',
#  ',',
#  ',',
#  'Epilepsy/diagnosis/physiopathology',
#  ',',
#  ',',
#  ',',
#  'Machine',
#  'Learning',
#  ',',
#  ',',
#  'Retrospective',
#  'Studies',
#  ',',
#  'Signal',
#  'Processing',
#  ',',
#  'Computer-Assisted',
#  ',',
#  ']',
#  '[',
#  ',',
#  'Cluster',
#  'Analysis',
#  ',',
#  ',',
#  'Potentials/physiology',
#  ',',
#  ',',
#  'Healthy',
#  'Volunteers',
#  ',',
#  ',',
#  ',',
#  'Memory',
#  ',',
#  'Short-Term/physiology',
#  ',',
#  'Motor',
#  'Cortex/physiology',
#  ',',
#  'Prefrontal',
#  'Cortex/physiology',
#  ',',
#  'Theta',
#  'Rhythm/physiology',
#  ',',
#  'Transcranial',
#  'Magnetic',
#  'Stimulation',
#  ',',
#  ']',
#  '[',
#  ',',
#  ',',
#  'Anxiety/therapy',
#  ',',
#  'Biofeedback',
#  ',',
#  'Psychology/methods',
#  ',',
#  ',',
#  'Chronic',
#  'Disease',
#  ',',
#  'Depression/therapy',
#  ',',
#  ',',
#  ',',
#  'Heart',
#  'Rate/physiology',
#  ',',
#  ',',
#  ',',
#  ']',
#  '[',
#  'Algorithms',
#  ',',
#  'Electrooculography/methods',
#  ',',
#  ',',
#  'Saccades',
#  ']',
#  '[',
#  ',',
#  'Attention',
#  'Deficit',
#  'Disorder',
#  'Hyperactivity/epidemiology/etiology',
#  ',',
#  ',',
#  'Comorbidity',
#  ',',
#  'Epilepsy/epidemiology/etiology',
#  ',',
#  ',',
#  ',',
#  'Muscular',
#  'Dystrophy',
#  ',',
#  'Duchenne/complications',
#  ',',
#  'Obsessive-Compulsive',
#  'Disorder/epidemiology/etiology',
#  ',',
#  'Prevalence',
#  ',',
#  'Seizures/epidemiology/etiology',
#  ',',
#  'Surveys',
#  'Questionnaires',
#  ']',
#  '[',
#  'Action',
#  'Potentials',
#  ',',
#  ',',
#  'Brain',
#  'Mapping',
#  ',',
#  'Cluster',
#  'Analysis',
#  ',',
#  'Data',
#  'Interpretation',
#  ',',
#  'Statistical',
#  ',',
#  'Diagnosis',
#  ',',
#  'Computer-Assisted',
#  ',',
#  'Electrodes',
#  ',',
#  'Electroencephalography/instrumentation/methods/statistics',
#  '&',
#  'numerical',
#  'data',
#  ',',
#  'Epilepsy/diagnosis/physiopathology',
#  ',',
#  ',',
#  'Gamma',
#  'Rhythm',
#  ',',
#  ',',
#  ',',
#  'Scalp',
#  ',',
#  'Seizures/diagnosis/physiopathology',
#  ',',
#  'Signal',
#  'Processing',
#  ',',
#  'Computer-Assisted',
#  ',',
#  'Spatio-Temporal',
#  'Analysis',
#  ',',
#  ']',
#  '[',
#  ',',
#  'Anticonvulsants/therapeutic',
#  'use',
#  ',',
#  ',',
#  'Cost',
#  'Illness',
#  ',',
#  'Electroencephalography/methods/statistics',
#  '&',
#  'numerical',
#  'data',
#  ',',
#  'Electronic',
#  'Health',
#  'Records/statistics',
#  '&',
#  'numerical',
#  'data',
#  ',',
#  'Epilepsy',
#  ',',
#  'Reflex/physiopathology/therapy',
#  ',',
#  ',',
#  ',',
#  ',',
#  'Retrospective',
#  'Studies',
#  ',',
#  'Treatment',
#  'Outcome',
#  ']',
#  '[',
#  'Acetamides/pharmacology',
#  ',',
#  ',',
#  'Dose-Response',
#  'Relationship',
#  ',',
#  'Drug',
#  ',',
#  'Electrocorticography/drug',
#  'effects',
#  ',',
#  'Gene',
#  'Expression/drug',
#  'effects',
#  ',',
#  ',',
#  'Microinjections',
#  ',',
#  'Motor',
#  'Cortex/metabolism/physiopathology',
#  ',',
#  'Penicillins/pharmacology',
#  ',',
#  'Rats',
#  ',',
#  'Seizures/chemically',
#  'induced/physiopathology/prevention',
#  '&',
#  'control',
#  ',',
#  'Vesicular',
#  'Glutamate',
#  'Transport',
#  'Protein',
#  '1/biosynthesis',
#  ',',
#  'Vesicular',
#  'Inhibitory',
#  'Amino',
#  'Acid',
#  'Transport',
#  'Proteins/biosynthesis',
#  ']',
#  '[',
#  'Brain/physiology',
#  ',',
#  'Brain',
#  'Mapping/methods',
#  ',',
#  'Color',
#  'Perception/physiology',
#  ',',
#  'Contrast',
#  'Sensitivity/physiology',
#  ',',
#  ',',
#  'Potentials/physiology',
#  ',',
#  ',',
#  'Pattern',
#  'Recognition',
#  ',',
#  'Visual/physiology',
#  ',',
#  'Photic',
#  'Stimulation',
#  ',',
#  'Signal',
#  'Processing',
#  ',',
#  'Computer-Assisted',
#  ']',
#  '[',
#  ',',
#  ...]

# %% [markdown]
# <h3>5.4 Clean the Data: Everything Else</h3>
# <p>Trouble with dataset that large is we cannot see the whole picture for sure. We will pass throught a cleaning loop including a few elements. We're not certain that all these steps are useful. On more than 10 000 MeSH terms there might be some extra spaces, there might be some single charactere completly meaningless here and there.</p><p>There are some single numbers like '15'. Again we are limited by our own knowledge.</p><p>We'll use lemmatization in the same perspective. We cannot be certain of the usefulness of the feature. But since we're cleaning the data and if it is possible to lemmatize, in general it would be better if our datasets are lemmatized. This is a little uncertain concerning keywords. Again there's a degre of ambiguity. Above all they are 'in case' instructions. </p>

# %%
docMesh2018 = []

stemmer = WordNetLemmatizer()

for sen in range(0, len(filtSent2018)):
    # Remaining special characters
    doc1 = re.sub(r'\W', ' ', str(filtSent2018[sen]))
    # single characters
    doc1 = re.sub(r'\s+[a-zA-Z]\s+', ' ', doc1)
    # multiple spaces to single space
    doc1 = re.sub(r'\s+', ' ', doc1, flags=re.I)
    # Lowercase
    doc1 = doc1.lower()
    # Lemmatization
    doc1 = doc1.split()
     
    doc1 = [stemmer.lemmatize(word) for word in doc1]
    doc1 = ' '.join(doc1)
    
    docMesh2018.append(doc1)
    docMesh2018 = [i for i in docMesh2018 if i]

# %%
docMesh2019 = []

stemmer = WordNetLemmatizer()

for sen in range(0, len(filtSent2019)):
    # Remaining special characters
    doc2 = re.sub(r'\W', ' ', str(filtSent2019[sen]))
    # single characters
    doc2 = re.sub(r'\s+[a-zA-Z]\s+', ' ', doc2)
    # multiple spaces to single space
    doc2 = re.sub(r'\s+', ' ', doc2, flags=re.I)
    # Lowercase
    doc2 = doc2.lower()
    # Lemmatization
    doc2 = doc2.split()
     
    doc2 = [stemmer.lemmatize(word) for word in doc2]
    doc2 = ' '.join(doc2)
    
    docMesh2019.append(doc2)
    docMesh2019 = [i for i in docMesh2019 if i]

# %%
docMesh2020 = []

stemmer = WordNetLemmatizer()

for sen in range(0, len(filtSent2020)):
    # Remaining special characters
    doc3 = re.sub(r'\W', ' ', str(filtSent2020[sen]))
    # single characters
    doc3 = re.sub(r'\s+[a-zA-Z]\s+', ' ', doc3)
    # multiple spaces to single space
    doc3 = re.sub(r'\s+', ' ', doc3, flags=re.I)
    # Lowercase
    doc3 = doc3.lower()
    # Lemmatization
    doc3 = doc3.split()
     
    doc3 = [stemmer.lemmatize(word) for word in doc3]
    doc3 = ' '.join(doc3)
    
    docMesh2020.append(doc3)
    docMesh2020 = [i for i in docMesh2020 if i]

# %%
docMesh2020
# Out:
# ['brain physiology',
#  'brain computer',
#  'interface',
#  'covid 19 psychology',
#  'mental',
#  'process physiology',
#  'occupational',
#  'health statistic',
#  'numerical',
#  'data',
#  'ocean',
#  'sea',
#  'pattern',
#  'recognition',
#  'automated method',
#  'brain physiology',
#  'chronic',
#  'pain',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'pain',
#  'management',
#  'pain',
#  'perception',
#  'professional patient',
#  'relation',
#  'cerebral',
#  'cortex diagnostic',
#  'imaging physiology',
#  'electroencephalography standard',
#  'functional',
#  'neuroimaging standard',
#  'magnetoencephalography standard',
#  'nerve',
#  'net diagnostic',
#  'imaging physiology',
#  'sensitivity',
#  'specificity',
#  '80',
#  'brain diagnostic',
#  'imaging pathology',
#  'image',
#  'interpretation',
#  'computer assisted method',
#  'magnetic',
#  'resonance',
#  'imaging method',
#  'middle',
#  'neuroimaging method',
#  'seizure diagnostic',
#  'imaging pathology',
#  'potential physiology',
#  'feedback',
#  'sensory physiology',
#  'pitch',
#  'perception physiology',
#  'singing',
#  'voice physiology',
#  'anticonvulsant administration',
#  'dosage adverse',
#  'effect',
#  'chemotherapy',
#  'adjuvant method',
#  'preschool',
#  'dose response',
#  'relationship',
#  'drug',
#  'double blind',
#  'drug',
#  'therapy',
#  'combination method',
#  'epilepsy',
#  'partial drug',
#  'therapy',
#  'pregabalin administration',
#  'dosage adverse',
#  'effect',
#  'seizure drug',
#  'therapy',
#  'video',
#  'recording',
#  'epilepsy',
#  'reflex diagnostic',
#  'imaging physiopathology psychology',
#  'feeding',
#  'behavior physiology psychology',
#  'seizure diagnostic',
#  'imaging physiopathology psychology',
#  'stereotaxic',
#  'technique',
#  'anterior',
#  'thalamic',
#  'nucleus physiology',
#  'arousal physiology',
#  'cohort',
#  'study',
#  'deep',
#  'brain',
#  'stimulation method psychology',
#  'epilepsy psychology therapy',
#  'relaxation physiology psychology',
#  'retrospective',
#  'study',
#  'wakefulness physiology',
#  'ear diagnostic',
#  'epilepsy diagnosis diagnostic',
#  'middle',
#  'scalp diagnostic',
#  'wearable',
#  'electronic',
#  'device',
#  'amyotrophic',
#  'lateral',
#  'sclerosis physiopathology rehabilitation',
#  'brain physiology',
#  'brain computer',
#  'interface trend',
#  'event related',
#  'potential',
#  'p300 physiology',
#  'bayes',
#  'theorem',
#  'beta',
#  'rhythm physiology',
#  'cerebral',
#  'cortex physiology',
#  'cortical',
#  'synchronization physiology',
#  'cue',
#  'functional',
#  'neuroimaging',
#  'gamma',
#  'rhythm physiology',
#  'healthy',
#  'volunteer',
#  'magnetoencephalography',
#  'motor',
#  'cortex physiology',
#  'uncertainty',
#  'autistic',
#  'disorder complication physiopathology',
#  'brain diagnostic',
#  'potential',
#  'semantics',
#  'sex',
#  'characteristic',
#  'speech',
#  'speech',
#  'perception',
#  'anticipation',
#  'psychological physiology',
#  'cerebral',
#  'cortex physiology',
#  'emotion physiology',
#  'potential physiology',
#  'pattern',
#  'recognition',
#  'physiological physiology',
#  'recognition',
#  'psychology physiology',
#  'psychophysiologic',
#  'disorder diagnosis prevention',
#  'control therapy',
#  'seizure diagnosis prevention',
#  'control therapy',
#  'brain physiopathology',
#  'leg physiopathology',
#  'middle',
#  'movement physiology',
#  'polysomnography method',
#  'restless',
#  'leg',
#  'syndrome physiopathology',
#  'retrospective',
#  'study',
#  'sleep physiology',
#  'sleep',
#  'stage physiology',
#  'auditory',
#  'perception physiology',
#  'potential',
#  'auditory physiology',
#  'inhibition',
#  'psychological',
#  'principal',
#  'component',
#  'analysis',
#  'reaction',
#  'time physiology',
#  'auditory',
#  'perception',
#  'comprehension',
#  'eye',
#  'eye',
#  'movement',
#  'measurement',
#  'fixation',
#  'ocular',
#  'individuality',
#  'middle',
#  'mouth',
#  'noise',
#  'speech',
#  'perception',
#  'visual',
#  'perception',
#  'cluster',
#  'analysis',
#  'corpus',
#  'striatum cytology physiology',
#  'phase',
#  'synchronization',
#  'electrophysiology method statistic',
#  'numerical',
#  'data',
#  'gyrus',
#  'cinguli cytology physiology',
#  'learning physiology',
#  'macaca',
#  'mulatta',
#  'nerve',
#  'net',
#  'neuron physiology',
#  'prefrontal',
#  'cortex cytology physiology',
#  'reward',
#  'cross cultural',
#  'comparison',
#  'cross sectional',
#  'study',
#  'electroencephalography method trend',
#  'hospitalization trend',
#  'internationality',
#  'medical',
#  'history',
#  'taking method',
#  'middle',
#  'psychophysiologic',
#  'disorder ethnology physiopathology psychology',
#  'retrospective',
#  'study',
#  'seizure ethnology physiopathology psychology',
#  'administration',
#  'intranasal',
#  'double blind',
#  'phase',
#  'synchronization drug',
#  'effect',
#  'oxytocin administration',
#  'dosage metabolism pharmacology',
#  'pilot',
#  'project',
#  'placebo',
#  'effect',
#  'sensorimotor',
#  'cortex drug',
#  'effect physiology',
#  'social',
#  'behavior',
#  'social',
#  'perception',
#  'healthy',
#  'volunteer',
#  'middle',
#  'motor',
#  'cortex physiology',
#  'transcranial',
#  'magnetic',
#  'stimulation',
#  'brain computer',
#  'interface',
#  'consciousness',
#  'disorder diagnosis',
#  'middle',
#  'prognosis',
#  'algorithm',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity physiopathology',
#  'beta',
#  'rhythm physiology',
#  'neurofeedback',
#  'software',
#  'theta',
#  'rhythm physiology',
#  'alpha',
#  'rhythm physiology',
#  'attention physiology',
#  'brain physiology',
#  'memory',
#  'short term physiology',
#  'photic',
#  'stimulation',
#  'reaction',
#  'time physiology',
#  'sensory',
#  'gating physiology',
#  'visual',
#  'perception physiology',
#  'auditory',
#  'pathway physiology',
#  'auditory',
#  'perception physiology',
#  'brain',
#  'mapping',
#  'potential physiology',
#  'psychomotor',
#  'performance physiology',
#  'temporal',
#  'lobe physiology',
#  'decision',
#  'tree',
#  'electrooculography',
#  'image',
#  'processing',
#  'computer assisted',
#  'monte',
#  'carlo',
#  'neural',
#  'network',
#  'computer',
#  'spinocerebellar',
#  'ataxia diagnosis',
#  'cerebral',
#  'cortex physiology',
#  'comprehension physiology',
#  'potential physiology',
#  'functional',
#  'laterality physiology',
#  'imagination physiology',
#  'middle',
#  'pattern',
#  'recognition',
#  'visual physiology',
#  'space',
#  'perception physiology',
#  'speech',
#  'perception physiology',
#  'electric',
#  'conductivity',
#  'electrocardiography',
#  'electrode classification',
#  'electromyography',
#  'electrooculography',
#  'abrin blood poisoning',
#  'brain',
#  'disease chemically',
#  'induced',
#  'drug',
#  'overdose mortality',
#  'fatal',
#  'outcome',
#  'suicide',
#  'attempted',
#  'drug',
#  'resistant',
#  'epilepsy surgery',
#  'electrocorticography',
#  'epilepsy',
#  'temporal',
#  'lobe surgery',
#  'neurosurgical',
#  'procedure method',
#  'palliative',
#  'care method',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity physiopathology',
#  'beta',
#  'rhythm physiology',
#  'brain',
#  'wave',
#  'electrode',
#  'electroencephalography instrumentation method',
#  'language',
#  'test',
#  'psychomotor',
#  'performance physiology',
#  'reading',
#  'rest',
#  'theta',
#  'rhythm physiology',
#  'cadherins genetics',
#  'preschool',
#  'database',
#  'genetic',
#  'epilepsy genetics physiopathology',
#  'mutation',
#  'russia',
#  'brain physiopathology',
#  'brain',
#  'wave',
#  'epilepsy diagnosis physiopathology surgery',
#  'sensitivity',
#  'specificity',
#  'treatment',
#  'outcome',
#  'algorithm',
#  'anticonvulsant therapeutic',
#  'use',
#  'clinical',
#  'trial',
#  'topic method',
#  'clobazam therapeutic',
#  'use',
#  'expert',
#  'testimony method',
#  'intellectual',
#  'disability diagnosis drug',
#  'therapy physiopathology',
#  'lennox',
#  'gastaut',
#  'syndrome diagnosis drug',
#  'therapy physiopathology',
#  'sleep physiology',
#  'triazoles therapeutic',
#  'use',
#  'potential',
#  'face',
#  'visual',
#  'perception',
#  'brain physiopathology',
#  'retrospective',
#  'study',
#  'seizure physiopathology',
#  'anticonvulsant therapeutic',
#  'use',
#  'brain',
#  'disease drug',
#  'therapy etiology genetics',
#  'epilepsy complication drug',
#  'therapy genetics',
#  'heterozygote',
#  'intellectual',
#  'disability genetics',
#  'mutation genetics',
#  'prognosis',
#  'spasm',
#  'infantile drug',
#  'therapy genetics',
#  'tumor',
#  'suppressor',
#  'protein genetics',
#  'ww',
#  'domain containing',
#  'oxidoreductase genetics',
#  'brain',
#  'disease diagnostic',
#  'imaging drug',
#  'therapy physiopathology',
#  'covid 19 diagnosis diagnostic',
#  'imaging drug',
#  'therapy physiopathology',
#  'corpus',
#  'callosum diagnostic',
#  'dyspnea physiopathology',
#  'exanthema physiopathology',
#  'fever physiopathology',
#  'glucocorticoid therapeutic',
#  'use',
#  'hallucination physiopathology',
#  'immunoglobulin',
#  'intravenous therapeutic',
#  'use',
#  'immunologic',
#  'factor therapeutic',
#  'use',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'methylprednisolone therapeutic',
#  'use',
#  'neurocognitive',
#  'disorder diagnostic',
#  'imaging physiopathology',
#  'sars cov 2',
#  'systemic',
#  'inflammatory',
#  'response',
#  'syndrome diagnostic',
#  'imaging drug',
#  'ntherapy physiopathology',
#  'tachypnea physiopathology',
#  'clinical',
#  'protocol',
#  'deception',
#  'event related',
#  'potential',
#  'p300 physiology',
#  'galvanic',
#  'skin',
#  'response physiology',
#  'memory',
#  'episodic',
#  'recognition',
#  'psychology physiology',
#  'aging',
#  'association',
#  'learning',
#  'memory',
#  'episodic',
#  'recognition',
#  'psychology',
#  'semantics',
#  'age',
#  'factor',
#  'anesthesia',
#  'intravenous method',
#  'body',
#  'mass',
#  'index',
#  'consciousness',
#  'monitor',
#  'monitoring',
#  'intraoperative method',
#  'retrospective',
#  'study',
#  'robotic',
#  'surgical',
#  'procedure method',
#  'sex',
#  'factor',
#  '80',
#  'brain physiology physiopathology',
#  'brain',
#  'mapping',
#  'cognition physiology',
#  'middle',
#  'rest physiology',
#  'signal',
#  'processing',
#  'computer assisted',
#  'wakefulness physiology',
#  'preschool',
#  'postural',
#  'orthostatic',
#  'tachycardia',
#  'syndrome',
#  'posture',
#  'retrospective',
#  'study',
#  'syncope',
#  'vasovagal',
#  'tilt table',
#  'test',
#  'cannabinoid',
#  'receptor',
#  'agonist pharmacology',
#  'disease',
#  'model',
#  'animal',
#  'electroencephalography drug',
#  'effect',
#  'epilepsy',
#  'absence drug',
#  'therapy physiopathology',
#  'rat',
#  'rat',
#  'transgenic',
#  'acoustic',
#  'stimulation',
#  'brain physiology',
#  'brain',
#  'mapping method',
#  'potential physiology',
#  'language',
#  'music',
#  'semantics',
#  'brain physiopathology',
#  'middle',
#  'perceptual',
#  'disorder diagnosis etiology physiopathology',
#  'reproducibility',
#  'result',
#  'signal',
#  'processing',
#  'computer assisted',
#  'stroke complication',
#  'cell',
#  'membrane',
#  'cerebral',
#  'cortex physiopathology',
#  'electrocorticography',
#  'epilepsy physiopathology',
#  'epilepsy',
#  'absence physiopathology',
#  'neuron',
#  'pyramidal',
#  'cell',
#  'rat',
#  'sensation',
#  'somatosensory',
#  'cortex physiopathology',
#  'thalamus physiopathology',
#  'vibrissa innervation',
#  'brain',
#  'cognition',
#  'neuron',
#  'walking',
#  'accelerometry method',
#  'cohort',
#  'study',
#  'confusion diagnosis physiopathology',
#  'exercise physiology',
#  'middle',
#  'seizure diagnosis physiopathology',
#  'sudden',
#  'unexpected',
#  'death',
#  'epilepsy prevention',
#  'control',
#  'brain computer',
#  'interface adverse',
#  'effect trend',
#  'cognition physiology',
#  'neurology instrumentation trend',
#  'nootropic',
#  'agent adverse',
#  'effect',
#  'anticonvulsant pharmacology therapeutic',
#  'use',
#  'cohort',
#  'study',
#  'electroencephalography drug',
#  'effect method',
#  'epilepsy',
#  'generalized diagnosis drug',
#  'therapy physiopathology',
#  'sleep',
#  'stage drug',
#  'effect physiology',
#  'cognition physiology',
#  'eye',
#  'movement',
#  'measurement',
#  'fixation',
#  'ocular physiology',
#  'problem',
#  'solving',
#  'pupil physiology',
#  'reproducibility',
#  'result',
#  'visual',
#  'perception physiology',
#  'brain physiology',
#  'brain computer',
#  'interface',
#  'electroencephalography classification method',
#  'emotion classification',
#  'machine',
#  'learning',
#  'pattern',
#  'recognition',
#  'automated method',
#  'fixation',
#  'ocular physiology',
#  'japan',
#  'motor',
#  'activity physiology',
#  'muscle',
#  'hypotonia physiopathology',
#  'mutation',
#  'missense',
#  'neurodevelopmental',
#  'disorder genetics physiopathology',
#  'snare',
#  'protein genetics',
#  'vesicle associated',
#  'membrane',
#  'protein',
#  '2 genetics',
#  'blinking physiology',
#  'dopamine physiology',
#  'potential',
#  'inhibition',
#  'psychological',
#  'neuropsychological',
#  'test',
#  'algorithm',
#  'computer',
#  'graphic',
#  'dominance',
#  'ocular physiology',
#  'eye tracking',
#  'technology',
#  'fixation',
#  'ocular physiology',
#  'smart',
#  'glass',
#  'user computer',
#  'interface',
#  'virtual',
#  'reality',
#  'visual',
#  'perception physiology',
#  'affect drug',
#  'effect',
#  'attention drug',
#  'effect',
#  'brain',
#  'cognition drug',
#  'effect',
#  'cross over',
#  'study',
#  'double blind',
#  'mangifera chemistry',
#  'memory drug',
#  'effect',
#  'memory',
#  'episodic',
#  'middle',
#  'nootropic',
#  'agent pharmacology',
#  'plant',
#  'extract pharmacology',
#  'plant',
#  'leaf chemistry',
#  'polyphenols pharmacology',
#  'xanthones pharmacology',
#  'airway',
#  'management',
#  'blood',
#  'glucose analysis',
#  'abuse therapy',
#  'electric',
#  'countershock',
#  'emergency',
#  'service',
#  'hospital',
#  'epinephrine therapeutic',
#  'use',
#  'extracorporeal',
#  'membrane',
#  'oxygenation',
#  'heart',
#  'arrest etiology therapy',
#  'heart',
#  'defect',
#  'congenital therapy',
#  'heart',
#  'rate',
#  'hypothermia complication therapy',
#  'hypothermia',
#  'induced',
#  'lung',
#  'disease therapy',
#  'parent',
#  'physical',
#  'examination',
#  'poisoning therapy',
#  'process',
#  'assessment',
#  'health',
#  'care',
#  'reference',
#  'value',
#  'respiratory',
#  'insufficiency therapy',
#  'respiratory',
#  'rate',
#  'resuscitation method',
#  'resuscitation',
#  'order',
#  'sepsis therapy',
#  'shock etiology therapy',
#  'vasoconstrictor',
#  'agent therapeutic',
#  'use',
#  'wound',
#  'injury therapy',
#  'potential physiology',
#  'multilingualism',
#  'photic',
#  'stimulation method',
#  'prefrontal',
#  'cortex physiology',
#  'psychomotor',
#  'performance physiology',
#  'reaction',
#  'time physiology',
#  'theta',
#  'rhythm physiology',
#  'transcranial',
#  'magnetic',
#  'stimulation method',
#  'anxiety',
#  'attention',
#  'case control',
#  'study',
#  'depression physiopathology',
#  'depressive',
#  'disorder',
#  'major physiopathology',
#  'emotion',
#  'middle',
#  'photic',
#  'stimulation',
#  'visual',
#  'field',
#  'visual',
#  'perception',
#  '14 3 3',
#  'protein cerebrospinal',
#  'fluid',
#  '80',
#  'biomarkers analysis',
#  'creutzfeldt jakob',
#  'syndrome diagnostic',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'middle',
#  'olfactory',
#  'mucosa',
#  'prion genetics',
#  'prospective',
#  'study',
#  'sensitivity',
#  'specificity',
#  'tau',
#  'protein cerebrospinal',
#  'fluid',
#  'depression therapy',
#  'music',
#  'neurofeedback',
#  'ego',
#  'potential physiology',
#  'mental',
#  'recall physiology',
#  'model',
#  'biological',
#  'motor',
#  'activity physiology',
#  'recognition',
#  'psychology physiology',
#  'social',
#  'perception',
#  'brain physiopathology',
#  'clinical',
#  'decision making',
#  'epilepsy diagnosis physiopathology surgery',
#  'neural',
#  'pathway physiopathology surgery',
#  'neurosurgical',
#  'procedure method',
#  'preoperative',
#  'care method',
#  'seizure diagnosis physiopathology surgery',
#  'algorithm',
#  'brain computer',
#  'interface',
#  'data',
#  'compression',
#  'signal',
#  'processing',
#  'computer assisted',
#  'cerebral',
#  'cortex physiopathology',
#  'deep',
#  'learning',
#  'electroencephalography method standard',
#  'model',
#  'theoretical',
#  'seizure diagnosis',
#  'sensitivity',
#  'specificity',
#  'signal',
#  'processing',
#  'computer assisted',
#  'brain physiology',
#  'emotion',
#  'potential',
#  'functional',
#  'laterality',
#  'inhibition',
#  'psychological',
#  'alpha',
#  'rhythm',
#  'brain',
#  'ischemia diagnosis etiology physiopathology',
#  'delta',
#  'rhythm',
#  'early',
#  'diagnosis',
#  'predictive',
#  'value',
#  'test',
#  'subarachnoid',
#  'hemorrhage complication diagnosis physiopathology',
#  'time',
#  'factor',
#  'vasospasm',
#  'intracranial diagnosis etiology physiopathology',
#  'behavior',
#  'brain physiology',
#  'communication',
#  'electrode',
#  'gamma',
#  'rhythm physiology',
#  'model',
#  'neurological',
#  'task',
#  'performance',
#  'analysis',
#  'time',
#  'factor',
#  '80',
#  'alzheimer',
#  'disease diagnosis physiopathology psychology',
#  'cognitive',
#  'dysfunction diagnosis physiopathology psychology',
#  'middle',
#  'polysomnography method',
#  'prospective',
#  'study',
#  'sleep physiology',
#  'bradycardia etiology',
#  'electrocardiography',
#  'electrocorticography',
#  'neurotoxin toxicity',
#  'rat',
#  'rat',
#  'wistar',
#  'seizure chemically',
#  'induced complication physiopathology',
#  'sudden',
#  'unexpected',
#  'death',
#  'epilepsy etiology',
#  'tachycardia etiology',
#  'tetanus',
#  'toxin toxicity',
#  'electric',
#  'stimulation method',
#  'electrode',
#  'implanted',
#  'functional',
#  'laterality physiology',
#  'motor',
#  'cortex physiopathology',
#  'neural',
#  'inhibition physiology',
#  'pyramidal',
#  'cell physiology',
#  'rat',
#  'rat',
#  'wistar',
#  'recovery',
#  'function physiology',
#  'stroke physiopathology',
#  'theta',
#  'rhythm physiology',
#  'aging',
#  'anesthesia',
#  'intravenous',
#  'anesthetic',
#  'intravenous administration',
#  'dosage',
#  'brain physiopathology',
#  'consciousness',
#  'entropy',
#  'middle',
#  'propofol administration',
#  'dosage',
#  'prospective',
#  'study',
#  'pain',
#  'management',
#  'phantom',
#  'limb',
#  'pilot',
#  'project',
#  'somatosensory',
#  'cortex',
#  'transcutaneous',
#  'electric',
#  'nerve',
#  'stimulation',
#  'augmented',
#  'reality',
#  'computer',
#  'graphic',
#  'eye tracking',
#  'technology',
#  'fixation',
#  'ocular physiology',
#  'task',
#  'performance',
#  'analysis',
#  'beta',
#  'rhythm physiology',
#  'frontal',
#  'lobe physiopathology',
#  'lower',
#  'extremity physiopathology',
#  'middle',
#  'movement physiology',
#  ...]

# %%
docMesh2019
# Out:
# ['algorithm',
#  'attention',
#  'auditory',
#  'perception',
#  'electroencephalography instrumentation',
#  'hearing',
#  'aid',
#  'magnetoencephalography instrumentation',
#  'speech',
#  'perception',
#  'brain physiology',
#  'computer assisted',
#  'instruction method',
#  'forecasting',
#  'learning physiology',
#  'motivation physiology',
#  'photic',
#  'stimulation method',
#  'anticonvulsant',
#  'preschool',
#  'follow up',
#  'study',
#  'methylprednisolone therapeutic',
#  'use',
#  'retrospective',
#  'study',
#  'sleep',
#  'status',
#  'epilepticus drug',
#  'therapy',
#  'association',
#  'learning physiology',
#  'attention physiology',
#  'cue',
#  'eye',
#  'movement',
#  'measurement',
#  'pattern',
#  'recognition',
#  'visual physiology',
#  'psychomotor',
#  'performance physiology',
#  'uncertainty',
#  'action',
#  'potential',
#  'brain physiology',
#  'brain',
#  'wave',
#  'cortical',
#  'synchronization',
#  'microelectrodes',
#  'periodicity',
#  'rat',
#  'wistar',
#  'tissue',
#  'culture',
#  'technique method',
#  'azepines pharmacology',
#  'cataplexy drug',
#  'therapy genetics physiopathology',
#  'hypothalamus drug',
#  'effect metabolism physiology physiopathology',
#  'transgenic',
#  'mutation',
#  'narcolepsy drug',
#  'therapy genetics physiopathology',
#  'nerve',
#  'tissue',
#  'protein genetics metabolism',
#  'orexin',
#  'receptor',
#  'antagonist pharmacology',
#  'orexin',
#  'receptor genetics metabolism',
#  'orexins metabolism',
#  'polysomnography',
#  'sleep physiology',
#  'sleep',
#  'aid',
#  'pharmaceutical pharmacology',
#  'sleep',
#  'initiation',
#  'maintenance',
#  'disorder drug',
#  'therapy genetics physiopathology',
#  'synapsis drug',
#  'effect metabolism',
#  'triazoles pharmacology',
#  'wakefulness physiology',
#  'healthy',
#  'volunteer',
#  'motor',
#  'cortex physiology',
#  'neuron physiology',
#  'transcranial',
#  'magnetic',
#  'stimulation',
#  'attention',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity drug',
#  'therapy physiopathology',
#  'brain physiopathology',
#  'magnetic',
#  'resonance',
#  'imaging method',
#  'methylphenidate metabolism therapeutic',
#  'use',
#  'nerve',
#  'net drug',
#  'effect',
#  'parietal',
#  'lobe physiopathology',
#  'algorithm',
#  'alpha',
#  'rhythm physiology',
#  'brain physiology',
#  'magnetoencephalography',
#  'signal',
#  'processing',
#  'computer assisted',
#  'attention physiology',
#  'cue',
#  'eye',
#  'movement',
#  'measurement',
#  'fixation',
#  'ocular physiology',
#  'interpersonal',
#  'relation',
#  'reaction',
#  'time physiology',
#  'schizophrenia physiopathology',
#  'social',
#  'perception',
#  'adrenergic',
#  'neuron drug',
#  'effect physiology',
#  'anesthesia',
#  'general',
#  'anesthetic',
#  'intravenous',
#  'arousal physiology',
#  'clozapine analog',
#  'derivative pharmacology',
#  'delayed',
#  'emergence',
#  'anesthesia physiopathology',
#  'designer',
#  'drug pharmacology',
#  'genetic',
#  'vector administration',
#  'dosage',
#  'intralaminar',
#  'thalamic',
#  'nucleus drug',
#  'effect physiopathology',
#  'inbred',
#  'c57bl',
#  'nerve',
#  'ending drug',
#  'effect physiology',
#  'norepinephrine pharmacology',
#  'patch clamp',
#  'technique',
#  'propofol',
#  'random',
#  'allocation',
#  'receptor',
#  'muscarinic',
#  'm3 drug',
#  'effect physiology',
#  'receptor',
#  'adrenergic',
#  'alpha 1 drug',
#  'effect physiology',
#  'recombinant',
#  'protein drug',
#  'effect metabolism',
#  'reflex',
#  'righting drug',
#  'effect',
#  'single blind',
#  'specific',
#  'pathogen free',
#  'organism',
#  'synaptic',
#  'potential drug',
#  'effect physiology',
#  'esthetic',
#  'eye',
#  'movement',
#  'measurement instrumentation',
#  'eye',
#  'movement physiology',
#  'fixation',
#  'ocular physiology',
#  'personal',
#  'satisfaction',
#  'postoperative',
#  'care',
#  'rhytidoplasty psychology',
#  '80',
#  'brain diagnostic',
#  'imaging pathology',
#  'image',
#  'interpretation',
#  'computer assisted method',
#  'magnetic',
#  'resonance',
#  'imaging method',
#  'middle',
#  'neuroimaging method',
#  'seizure diagnostic',
#  'imaging pathology',
#  'asian',
#  'continental',
#  'ancestry',
#  'group genetics',
#  'creutzfeldt jakob',
#  'syndrome genetics',
#  'point',
#  'mutation',
#  'prion',
#  'protein genetics',
#  'anticonvulsant therapeutic',
#  'use',
#  'critical',
#  'care',
#  'critical',
#  'illness',
#  'randomized',
#  'controlled',
#  'trial',
#  'topic',
#  'seizure drug',
#  'therapy',
#  'status',
#  'epilepticus drug',
#  'therapy',
#  'eye',
#  'movement',
#  'measurement',
#  'eye',
#  'movement',
#  'fixation',
#  'ocular',
#  'language',
#  'reading',
#  'saccade',
#  'brain metabolism physiology',
#  'central',
#  'nervous',
#  'system metabolism physiology',
#  'cerebrovascular',
#  'circulation physiology',
#  'epilepsy physiopathology',
#  'hemodynamics physiology',
#  'rat',
#  'rat',
#  'inbred',
#  'wf',
#  'status',
#  'epilepticus physiopathology',
#  'brain',
#  'injury complication physiopathology',
#  'electrocorticography method',
#  'epilepsy etiology physiopathology',
#  'nonlinear',
#  'dynamic',
#  'rat',
#  'signal',
#  'processing',
#  'computer assisted',
#  'cardiopulmonary',
#  'resuscitation adverse',
#  'effect method',
#  'coma diagnosis etiology',
#  'cortical',
#  'excitability',
#  'france epidemiology',
#  'heart',
#  'arrest complication epidemiology therapy',
#  'middle',
#  'nervous',
#  'system',
#  'disease diagnosis etiology',
#  'outcome',
#  'assessment',
#  'health',
#  'care',
#  'predictive',
#  'value',
#  'test',
#  'prognosis',
#  'registry statistic',
#  'numerical',
#  'data',
#  'sensitivity',
#  'specificity',
#  'epilepsy',
#  'reflex diagnostic',
#  'imaging physiopathology psychology',
#  'feeding',
#  'behavior physiology psychology',
#  'seizure diagnostic',
#  'imaging physiopathology psychology',
#  'stereotaxic',
#  'technique',
#  '80',
#  'diagnosis',
#  'computer assisted method',
#  'epilepsy diagnosis physiopathology',
#  'false',
#  'positive',
#  'reaction',
#  'middle',
#  'neurophysiological',
#  'monitoring method',
#  'nursing',
#  'care',
#  'patient',
#  'admission',
#  'pattern',
#  'recognition',
#  'automated method',
#  'retrospective',
#  'study',
#  'seizure diagnosis physiopathology',
#  'software',
#  'time to treatment',
#  'video',
#  'recording',
#  '80',
#  'arousal physiology',
#  'autonomic',
#  'nervous',
#  'system physiopathology',
#  'heart',
#  'rate physiology',
#  'middle',
#  'panic physiology',
#  'respiratory',
#  'rate physiology',
#  'retrospective',
#  'study',
#  'seizure diagnosis physiopathology psychology',
#  'brain',
#  'concussion complication physiopathology',
#  'eye',
#  'movement',
#  'measurement',
#  'fixation',
#  'ocular physiology',
#  'middle',
#  'ocular',
#  'motility',
#  'disorder etiology physiopathology',
#  'saccade physiology',
#  'attention physiology',
#  'choice',
#  'behavior physiology',
#  'cue',
#  'potential physiology',
#  'executive',
#  'function physiology',
#  'inhibition',
#  'psychological',
#  'psychomotor',
#  'performance physiology',
#  'reaction',
#  'time physiology',
#  'task',
#  'performance',
#  'analysis',
#  'attention',
#  'double blind',
#  'event related',
#  'potential',
#  'p300',
#  'potential',
#  'healthy',
#  'volunteer',
#  'meditation',
#  'memory',
#  'short term',
#  'mobile',
#  'application',
#  'multitasking',
#  'behavior',
#  'brain physiology',
#  'discrimination',
#  'psychological physiology',
#  'facial',
#  'recognition physiology',
#  'middle',
#  'recognition',
#  'psychology physiology',
#  'attention physiology',
#  'auditory',
#  'perception physiology',
#  'brain',
#  'mapping',
#  'conflict',
#  'psychological',
#  'prefrontal',
#  'cortex physiology',
#  'transcranial',
#  'direct',
#  'current',
#  'stimulation',
#  'acetamide pharmacology',
#  'dose response',
#  'relationship',
#  'drug',
#  'electrocorticography drug',
#  'effect',
#  'gene',
#  'expression drug',
#  'effect',
#  'microinjections',
#  'motor',
#  'cortex metabolism physiopathology',
#  'penicillin pharmacology',
#  'rat',
#  'seizure chemically',
#  'induced physiopathology prevention',
#  'control',
#  'vesicular',
#  'glutamate',
#  'transport',
#  'protein',
#  '1 biosynthesis',
#  'vesicular',
#  'inhibitory',
#  'amino',
#  'acid',
#  'transport',
#  'protein biosynthesis',
#  'brain computer',
#  'interface',
#  'imagination',
#  'machine',
#  'learning',
#  'model',
#  'neurological',
#  'attention physiology',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity physiopathology psychology therapy',
#  'behavior',
#  'therapy method',
#  'brain physiopathology',
#  'cognitive',
#  'behavioral',
#  'therapy method',
#  'combined',
#  'modality',
#  'therapy',
#  'potential physiology',
#  'exercise',
#  'exercise',
#  'therapy method',
#  'pilot',
#  'project',
#  'reaction',
#  'time',
#  'treatment',
#  'outcome',
#  'ear diagnostic',
#  'epilepsy diagnosis diagnostic',
#  'middle',
#  'scalp diagnostic',
#  'wearable',
#  'electronic',
#  'device',
#  'agenesis',
#  'corpus',
#  'callosum diagnostic',
#  'imaging pathology',
#  'diagnosis',
#  'differential',
#  'magnetic',
#  'resonance',
#  'imaging method',
#  'choice',
#  'behavior',
#  'decision',
#  'making',
#  'potential',
#  'healthy',
#  'volunteer',
#  'model',
#  'neurological',
#  'avoidance',
#  'learning',
#  'behavior',
#  'animal',
#  'body',
#  'weight',
#  'brain metabolism pathology',
#  'carbohydrate',
#  'metabolism',
#  'inborn',
#  'error genetics metabolism physiopathology',
#  'disease',
#  'model',
#  'animal',
#  'embryo',
#  'loss genetics pathology',
#  'glucose cerebrospinal',
#  'fluid metabolism',
#  'glucose',
#  'transporter',
#  'type',
#  '1 genetics metabolism',
#  'heterozygote',
#  'homozygote',
#  'kinetics',
#  'learning',
#  'mutant',
#  'strain',
#  'monosaccharide',
#  'transport',
#  'protein deficiency genetics metabolism',
#  'motor',
#  'activity',
#  'mutation',
#  'missense genetics',
#  'seizure genetics pathology physiopathology',
#  'sleep physiology',
#  'transcription',
#  'genetic',
#  'wakefulness physiology',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity psychology',
#  'beta',
#  'rhythm',
#  'biomarkers',
#  'brain',
#  'mapping method',
#  'cognition',
#  'decision',
#  'making',
#  'executive',
#  'function',
#  'neuropsychological',
#  'test',
#  'prognosis',
#  'rest',
#  'theta',
#  'rhythm',
#  'anticipation',
#  'psychological physiology',
#  'cerebral',
#  'cortex physiology',
#  'emotion physiology',
#  'potential physiology',
#  'pattern',
#  'recognition',
#  'physiological physiology',
#  'recognition',
#  'psychology physiology',
#  'psychophysiologic',
#  'disorder diagnosis prevention',
#  'control therapy',
#  'seizure diagnosis prevention',
#  'control therapy',
#  'alpha',
#  'rhythm physiology',
#  'brain physiology',
#  'brain',
#  'mapping',
#  'magnetoencephalography',
#  'memory',
#  'short term physiology',
#  'neuropsychological',
#  'test',
#  'reaction',
#  'time physiology',
#  'retention',
#  'psychology physiology',
#  'action',
#  'potential physiology',
#  'brain physiology',
#  'brain',
#  'mapping method',
#  'brain',
#  'wave physiology',
#  'electric',
#  'stimulation method',
#  'electrophysiological',
#  'phenomenon physiology',
#  'frontal',
#  'lobe physiology',
#  'macaca',
#  'mulatta physiology',
#  'neuron physiology',
#  'parietal',
#  'lobe physiology',
#  'photic',
#  'stimulation method',
#  'prefrontal',
#  'cortex physiology',
#  'autonomic',
#  'nervous',
#  'system physiology',
#  'depressive',
#  'disorder',
#  'major therapy',
#  'electrocardiography',
#  'electroconvulsive',
#  'therapy adverse',
#  'effect method',
#  'heart innervation physiology',
#  'heart',
#  'rate',
#  'middle',
#  'analysis',
#  'variance',
#  'biomarkers metabolism',
#  'brain physiology',
#  'emotion',
#  'entropy',
#  'anoctamins genetics',
#  'cognitive',
#  'dysfunction physiopathology',
#  'disease',
#  'progression',
#  'potential',
#  'somatosensory physiology',
#  'executive',
#  'function physiology',
#  'gene',
#  'recessive',
#  'middle',
#  'mutation',
#  'pedigree',
#  'spinocerebellar',
#  'ataxia genetics physiopathology',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity diagnosis physiopathology',
#  'beta',
#  'rhythm physiology',
#  'brain',
#  'mapping method',
#  'research',
#  'design',
#  'theta',
#  'rhythm physiology',
#  'beta',
#  'rhythm',
#  'borderline',
#  'personality',
#  'disorder physiopathology',
#  'case control',
#  'study',
#  'feedback',
#  'psychological',
#  'gambling',
#  'severity',
#  'illness',
#  'index',
#  'task',
#  'performance',
#  'analysis',
#  'age',
#  'factor',
#  'brain physiopathology',
#  'brain',
#  'wave',
#  'behavior',
#  'development',
#  'preschool',
#  'double blind',
#  'drug',
#  'resistant',
#  'epilepsy diagnosis physiopathology therapy',
#  'multicenter',
#  'study',
#  'topic',
#  'prospective',
#  'study',
#  'randomized',
#  'controlled',
#  'trial',
#  'topic',
#  'time',
#  'factor',
#  'treatment',
#  'outcome',
#  'vagus',
#  'nerve',
#  'stimulation adverse',
#  'effect',
#  'brain physiology',
#  'brain computer',
#  'interface',
#  'electrode',
#  'electroencephalography instrumentation',
#  'behavior',
#  'cognition',
#  'cognition',
#  'disorder diagnosis physiopathology psychology',
#  'cognitive',
#  'dysfunction diagnosis physiopathology psychology',
#  'disability',
#  'evaluation',
#  'disease',
#  'progression',
#  'middle',
#  'model',
#  'statistical',
#  'multiple',
#  'sclerosis',
#  'relapsing remitting diagnosis physiopathology psychology',
#  'neuropsychological',
#  'test',
#  'reaction',
#  'time',
#  'social',
#  'class',
#  'administration',
#  'intranasal',
#  'double blind',
#  'phase',
#  'synchronization drug',
#  'effect',
#  'oxytocin administration',
#  'dosage metabolism pharmacology',
#  'pilot',
#  'project',
#  'placebo',
#  'effect',
#  'sensorimotor',
#  'cortex drug',
#  'effect physiology',
#  'social',
#  'behavior',
#  'social',
#  'perception',
#  'bacteria isolation',
#  'purification',
#  'brain microbiology pathology',
#  'europe',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'meningoencephalitis diagnosis diagnostic',
#  'imaging microbiology pathology',
#  'parenchymal',
#  'tissue microbiology pathology',
#  'virus isolation',
#  'purification',
#  'artifact',
#  'brain physiology',
#  'electroencephalography method standard',
#  'magnetic',
#  'resonance',
#  'imaging method standard',
#  'alpha',
#  'rhythm',
#  'brain physiology',
#  'fixation',
#  'ocular',
#  'information',
#  'theory',
#  'memory',
#  'short term physiology',
#  'theta',
#  'rhythm',
#  'brain physiology',
#  'decision',
#  'making physiology',
#  'information',
#  'seeking',
#  'behavior',
#  'judgment physiology',
#  'self',
#  'concept',
#  'signal',
#  'processing',
#  'computer assisted',
#  'brain diagnostic',
#  'imaging physiology',
#  'electrode',
#  'electroencephalography instrumentation method',
#  'image',
#  'processing',
#  'computer assisted method',
#  'imaging',
#  'three dimensional method',
#  'magnetic',
#  'resonance',
#  'imaging instrumentation method',
#  'arousal physiology',
#  'diagnosis',
#  'differential',
#  'epilepsy diagnosis physiopathology',
#  'middle',
#  'polysomnography method',
#  'retrospective',
#  'study',
#  'sleep physiology',
#  'sleep',
#  'wake',
#  'disorder diagnosis physiopathology',
#  'video',
#  'recording method',
#  'aggression',
#  'potential',
#  'facial',
#  'recognition physiology',
#  'parietal',
#  'lobe',
#  'personality physiology',
#  'social',
#  'behavior',
#  'temporal',
#  'lobe',
#  'theta',
#  'rhythm',
#  'algorithm',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity physiopathology',
#  'beta',
#  'rhythm physiology',
#  'neurofeedback',
#  'software',
#  'theta',
#  'rhythm physiology',
#  'preschool',
#  'epilepsy',
#  'partial diagnosis',
#  'epilepsy',
#  'rolandic diagnosis',
#  'myoclonus diagnosis',
#  'retrospective',
#  'study',
#  'seizure etiology',
#  'brain',
#  'disease complication physiopathology',
#  'sleep physiology',
#  'status',
#  'epilepticus diagnosis physiopathology',
#  'syndrome',
#  'wakefulness physiology',
#  'auditory',
#  'pathway physiology',
#  'auditory',
#  'perception physiology',
#  'brain',
#  'mapping',
#  'potential physiology',
#  'psychomotor',
#  'performance physiology',
#  'temporal',
#  'lobe physiology',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity diagnosis pathology',
#  'neurofeedback method',
#  'auditory',
#  'perception physiology',
#  'brain physiology',
#  'memory',
#  'short term physiology',
#  'neural',
#  'pathway physiology',
#  'visual',
#  'perception physiology',
#  'family',
#  'middle',
#  'personality physiology',
#  'schizophrenia physiopathology',
#  'schizophrenic',
#  'psychology',
#  'brain',
#  'mapping',
#  'cerebral',
#  'cortex physiopathology',
#  'middle',
#  'nerve',
#  'net physiopathology',
#  'neural',
#  'pathway physiopathology',
#  'pain physiopathology',
#  'somatoform',
#  'disorder physiopathology',
#  'anticonvulsant therapeutic',
#  'use',
#  'brain',
#  'mapping method',
#  'drug',
#  'resistance',
#  'electric',
#  'stimulation',
#  'epilepsy',
#  'partial diagnosis drug',
#  'therapy physiopathology psychology',
#  'potential',
#  'somatosensory',
#  'median',
#  'nerve physiopathology',
#  'somatosensory',
#  'cortex physiopathology',
#  'time',
#  'factor',
#  'touch',
#  'touch',
#  'perception',
#  'attention physiology',
#  'cue',
#  'functional',
#  'laterality physiology',
#  'inhibition',
#  'psychological',
#  'parietal',
#  'lobe physiology',
#  'photic',
#  'stimulation',
#  'reaction',
#  'time physiology',
#  'transcranial',
#  'magnetic',
#  'stimulation',
#  'white',
#  'matter physiology',
#  'anesthetic',
#  'delirium',
#  'electric',
#  'stimulation',
#  'potential',
#  'somatosensory',
#  'hypnosis',
#  'limbic',
#  'system physiology',
#  'median',
#  'nerve physiology',
#  'physical',
#  'stimulation',
#  'somatosensory',
#  'cortex physiology',
#  'touch',
#  'perception physiology',
#  'attention physiology',
#  'autism',
#  'spectrum',
#  'disorder physiopathology psychology',
#  'case control',
#  'study',
#  'preschool',
#  'executive',
#  'function physiology',
#  'eye',
#  'movement',
#  'measurement',
#  'neuropsychological',
#  'test',
#  'photic',
#  'stimulation',
#  '80',
#  'middle',
#  'polysomnography method',
#  'reproducibility',
#  'result',
#  'sleep physiology',
#  'sleep',
#  'apnea',
#  'obstructive diagnosis physiopathology',
#  'wakefulness physiology',
#  'classical',
#  'lissencephalies',
#  'subcortical',
#  'band',
#  'heterotopias physiopathology',
#  'disease',
#  'model',
#  'animal',
#  'electrocorticography method',
#  'microtubule associated',
#  'protein metabolism',
#  'rat',
#  'wistar',
#  'seizure complication physiopathology',
#  'wakefulness physiology',
#  'algorithm',
#  'biocompatible',
#  'material chemistry',
#  'brain metabolism',
#  'electrode',
#  ...]

# %%
docMesh2018
# Out:
# ['brain',
#  'wave physiology',
#  'chorea etiology',
#  'epilepsy complication',
#  'brain physiopathology',
#  'encephalitis complication drug',
#  'therapy immunology',
#  'glucocorticoid therapeutic',
#  'use',
#  'intracellular',
#  'signaling',
#  'peptide',
#  'protein',
#  'methylprednisolone therapeutic',
#  'use',
#  'protein immunology',
#  'seizure complication drug',
#  'therapy immunology',
#  'anticipation',
#  'psychological physiology',
#  'auditory',
#  'perception physiology',
#  'cue',
#  'potential physiology',
#  'feedback',
#  'psychological physiology',
#  'psychomotor',
#  'performance physiology',
#  'reward',
#  'visual',
#  'perception physiology',
#  'brain pathology',
#  'canada',
#  'hypothermia',
#  'induced method',
#  'hypoxia ischemia',
#  'brain diagnosis',
#  'newborn',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'neurologic',
#  'examination',
#  'predictive',
#  'value',
#  'test',
#  'prospective',
#  'study',
#  'seizure diagnosis etiology',
#  'severity',
#  'illness',
#  'index',
#  'body',
#  'image',
#  'brain',
#  'mapping',
#  'cerebral',
#  'cortex diagnostic',
#  'imaging physiology physiopathology',
#  'drug',
#  'resistant',
#  'epilepsy diagnostic',
#  'imaging physiopathology',
#  'electric',
#  'stimulation',
#  'electrocorticography',
#  'implantable',
#  'neurostimulators',
#  'visual',
#  'perception physiology',
#  '80',
#  'alpha',
#  'rhythm physiology',
#  'alzheimer',
#  'disease diagnosis physiopathology',
#  'blinking physiology',
#  'cerebral',
#  'cortex physiopathology',
#  'cortical',
#  'synchronization physiology',
#  'lewy',
#  'body',
#  'disease diagnosis physiopathology',
#  'magnetoencephalography method',
#  'ocular',
#  'physiological',
#  'phenomenon',
#  'visual',
#  'perception physiology',
#  'anesthesia',
#  'general method statistic',
#  'numerical',
#  'data',
#  'electroencephalography method statistic',
#  'numerical',
#  'data',
#  'model',
#  'theoretical',
#  'stochastic',
#  'process',
#  'laboratory',
#  'biomarkers metabolism',
#  'drug',
#  'evaluation',
#  'preclinical method',
#  'drug related',
#  'side',
#  'effect',
#  'adverse',
#  'reaction diagnosis metabolism',
#  'pharmaceutical',
#  'preparation administration',
#  'dosage',
#  'risk',
#  'assessment',
#  'safety',
#  'seizure chemically',
#  'induced diagnosis metabolism',
#  'telemetry method',
#  'anxiety diagnosis psychology',
#  'attention physiology',
#  'cue',
#  'disgust',
#  'drug',
#  'labeling legislation',
#  'jurisprudence standard',
#  'electroencephalography method psychology',
#  'event related',
#  'potential',
#  'p300 physiology',
#  'fear physiology psychology',
#  'health',
#  'risk',
#  'behavior physiology',
#  'motivation physiology',
#  'photic',
#  'stimulation method',
#  'smoker psychology',
#  'tobacco',
#  'product legislation',
#  'jurisprudence standard',
#  '80',
#  'bayes',
#  'theorem',
#  'case control',
#  'study',
#  'electromyography',
#  'middle',
#  'motor',
#  'cortex physiology',
#  'neural',
#  'pathway physiology',
#  'parietal',
#  'lobe physiology',
#  'stroke physiopathology',
#  'association',
#  'learning physiology',
#  'attention physiology',
#  'cue',
#  'eye',
#  'movement',
#  'measurement',
#  'pattern',
#  'recognition',
#  'visual physiology',
#  'psychomotor',
#  'performance physiology',
#  'uncertainty',
#  'brain',
#  'stem physiology',
#  'judgment physiology',
#  'language',
#  'model',
#  'psychological',
#  'pitch',
#  'perception physiology',
#  'speech',
#  'perception physiology',
#  'brain diagnostic',
#  'imaging physiopathology',
#  'electroencephalography classification',
#  'epilepsy classification diagnosis physiopathology therapy',
#  'functional',
#  'laterality',
#  'periodicity',
#  'terminology',
#  'topic',
#  'potential physiology',
#  'functional',
#  'laterality physiology',
#  'memory',
#  'episodic',
#  'mental',
#  'recall physiology',
#  'recognition',
#  'psychology physiology',
#  'visual',
#  'field physiology',
#  'visual',
#  'perception physiology',
#  'arrhythmia',
#  'cardiac physiopathology',
#  'electrocardiography',
#  'epilepsy diagnosis',
#  'heart',
#  'rate physiology',
#  'predictive',
#  'value',
#  'test',
#  'seizure diagnosis',
#  'algorithm',
#  'emotion physiology',
#  'entropy',
#  'image',
#  'processing',
#  'computer assisted method',
#  'time',
#  'factor',
#  'eye',
#  'movement',
#  'measurement instrumentation standard',
#  'individuality',
#  'pupil physiology',
#  'brain pathology physiopathology',
#  'diffusion',
#  'tensor',
#  'imaging',
#  'inbred',
#  'c57bl',
#  'rat',
#  'rat',
#  'sprague dawley',
#  'status',
#  'epilepticus pathology physiopathology',
#  'alpha',
#  'rhythm physiology',
#  'cerebral',
#  'cortex physiology',
#  'mathematical',
#  'concept',
#  'nerve',
#  'net physiology',
#  'theta',
#  'rhythm physiology',
#  'thinking physiology',
#  'electromyography',
#  'isometric',
#  'contraction physiology',
#  'motor',
#  'neuron physiology',
#  'movement physiology',
#  'psychomotor',
#  'performance physiology',
#  'torque',
#  'age',
#  'distribution',
#  'angelman',
#  'syndrome complication physiopathology',
#  'anticonvulsant therapeutic',
#  'use',
#  'preschool',
#  'epilepsy',
#  'myoclonic drug',
#  'therapy epidemiology physiopathology',
#  'prevalence',
#  'quality',
#  'life',
#  'retrospective',
#  'study',
#  'seizure drug',
#  'therapy epidemiology',
#  'sleep',
#  'wake',
#  'disorder',
#  'anesthesia method',
#  'entropy',
#  'monitoring',
#  'intraoperative method',
#  'signal',
#  'processing',
#  'computer assisted',
#  'support',
#  'vector',
#  'machine',
#  'attention physiology',
#  'awareness physiology',
#  'cerebral',
#  'cortex physiology',
#  'consciousness physiology',
#  'cue',
#  'eye',
#  'movement physiology',
#  'model',
#  'psychological',
#  'space',
#  'perception physiology',
#  'visual',
#  'perception physiology',
#  'anticonvulsant administration',
#  'dosage',
#  'aphasia etiology',
#  'cerebral',
#  'cortex diagnostic',
#  'imaging pathology',
#  'epilepsy complication diagnosis drug',
#  'therapy',
#  'levetiracetam',
#  'magnetic',
#  'resonance',
#  'angiography',
#  'piracetam administration',
#  'dosage analog',
#  'derivative',
#  'brain',
#  'injury complication physiopathology',
#  'electrocorticography method',
#  'epilepsy etiology physiopathology',
#  'nonlinear',
#  'dynamic',
#  'rat',
#  'signal',
#  'processing',
#  'computer assisted',
#  'brain physiology',
#  'emotion physiology',
#  'potential physiology',
#  'facial',
#  'expression',
#  'facial',
#  'recognition physiology',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'photic',
#  'stimulation',
#  'united',
#  'state',
#  'veteran',
#  'acoustic',
#  'stimulation',
#  'analysis',
#  'variance',
#  'auditory',
#  'perception physiology',
#  'brain',
#  'mapping',
#  'potential physiology',
#  'music',
#  'photic',
#  'stimulation',
#  'pitch',
#  'perception physiology',
#  'reaction',
#  'time physiology',
#  'spatial',
#  'processing physiology',
#  'preschool',
#  'cohort',
#  'study',
#  'database',
#  'factual',
#  'epilepsy diagnosis physiopathology',
#  'machine',
#  'learning',
#  'retrospective',
#  'study',
#  'signal',
#  'processing',
#  'computer assisted',
#  'cluster',
#  'analysis',
#  'potential physiology',
#  'healthy',
#  'volunteer',
#  'memory',
#  'short term physiology',
#  'motor',
#  'cortex physiology',
#  'prefrontal',
#  'cortex physiology',
#  'theta',
#  'rhythm physiology',
#  'transcranial',
#  'magnetic',
#  'stimulation',
#  'anxiety therapy',
#  'biofeedback',
#  'psychology method',
#  'chronic',
#  'disease',
#  'depression therapy',
#  'heart',
#  'rate physiology',
#  'algorithm',
#  'electrooculography method',
#  'saccade',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity epidemiology etiology',
#  'comorbidity',
#  'epilepsy epidemiology etiology',
#  'muscular',
#  'dystrophy',
#  'duchenne complication',
#  'obsessive compulsive',
#  'disorder epidemiology etiology',
#  'prevalence',
#  'seizure epidemiology etiology',
#  'survey',
#  'questionnaire',
#  'action',
#  'potential',
#  'brain',
#  'mapping',
#  'cluster',
#  'analysis',
#  'data',
#  'interpretation',
#  'statistical',
#  'diagnosis',
#  'computer assisted',
#  'electrode',
#  'electroencephalography instrumentation method statistic',
#  'numerical',
#  'data',
#  'epilepsy diagnosis physiopathology',
#  'gamma',
#  'rhythm',
#  'scalp',
#  'seizure diagnosis physiopathology',
#  'signal',
#  'processing',
#  'computer assisted',
#  'spatio temporal',
#  'analysis',
#  'anticonvulsant therapeutic',
#  'use',
#  'cost',
#  'illness',
#  'electroencephalography method statistic',
#  'numerical',
#  'data',
#  'electronic',
#  'health',
#  'record statistic',
#  'numerical',
#  'data',
#  'epilepsy',
#  'reflex physiopathology therapy',
#  'retrospective',
#  'study',
#  'treatment',
#  'outcome',
#  'acetamide pharmacology',
#  'dose response',
#  'relationship',
#  'drug',
#  'electrocorticography drug',
#  'effect',
#  'gene',
#  'expression drug',
#  'effect',
#  'microinjections',
#  'motor',
#  'cortex metabolism physiopathology',
#  'penicillin pharmacology',
#  'rat',
#  'seizure chemically',
#  'induced physiopathology prevention',
#  'control',
#  'vesicular',
#  'glutamate',
#  'transport',
#  'protein',
#  '1 biosynthesis',
#  'vesicular',
#  'inhibitory',
#  'amino',
#  'acid',
#  'transport',
#  'protein biosynthesis',
#  'brain physiology',
#  'brain',
#  'mapping method',
#  'color',
#  'perception physiology',
#  'contrast',
#  'sensitivity physiology',
#  'potential physiology',
#  'pattern',
#  'recognition',
#  'visual physiology',
#  'photic',
#  'stimulation',
#  'signal',
#  'processing',
#  'computer assisted',
#  'brain',
#  'wave',
#  'deep',
#  'brain',
#  'stimulation',
#  'middle',
#  'neuralgia diagnosis physiopathology prevention',
#  'control',
#  'pain',
#  'measurement',
#  'periaqueductal',
#  'gray physiopathology surgery',
#  'principal',
#  'component',
#  'analysis',
#  'regression',
#  'analysis',
#  'severity',
#  'illness',
#  'index',
#  'thalamus physiopathology surgery',
#  'brain',
#  'mapping method',
#  'electrode',
#  'electroencephalography instrumentation method',
#  'potential',
#  'potential',
#  'somatosensory',
#  'neural',
#  'network',
#  'computer',
#  'photic',
#  'stimulation',
#  'somatosensory',
#  'cortex physiology',
#  'vision',
#  'ocular',
#  'agenesis',
#  'corpus',
#  'callosum diagnostic',
#  'imaging pathology',
#  'diagnosis',
#  'differential',
#  'magnetic',
#  'resonance',
#  'imaging method',
#  'aging',
#  'auditory',
#  'perception physiology',
#  'correlation',
#  'data',
#  'potential physiology',
#  'hearing physiology',
#  'memory physiology',
#  'middle',
#  'recognition',
#  'psychology physiology',
#  'time',
#  'factor',
#  'voice',
#  'epilepsy',
#  'nerve',
#  'net',
#  'neural',
#  'network',
#  'computer',
#  'signal',
#  'processing',
#  'computer assisted',
#  'support',
#  'vector',
#  'machine',
#  'brain physiology',
#  'electrode',
#  'implanted',
#  'potential physiology',
#  'potential',
#  'visual physiology',
#  'magnetic',
#  'resonance',
#  'imaging method',
#  'occipital',
#  'lobe physiology',
#  'parietal',
#  'lobe physiology',
#  'photic',
#  'stimulation method',
#  'visual',
#  'cortex physiology',
#  'brain physiology',
#  'brain',
#  'mapping',
#  'comprehension physiology',
#  'potential physiology',
#  'metaphor',
#  'psycholinguistics',
#  'semantics',
#  'brain diagnostic',
#  'imaging physiopathology',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'model',
#  'neurological',
#  'tinnitus physiopathology',
#  'brain physiology',
#  'computer',
#  'simulation',
#  'electrocorticography method',
#  'electrode',
#  'model',
#  'neurological',
#  'autonomic',
#  'nervous',
#  'system physiology',
#  'depressive',
#  'disorder',
#  'major therapy',
#  'electrocardiography',
#  'electroconvulsive',
#  'therapy adverse',
#  'effect method',
#  'heart innervation physiology',
#  'heart',
#  'rate',
#  'middle',
#  'brain physiology',
#  'potential physiology',
#  'feedback',
#  'feedback',
#  'psychological physiology',
#  'learning physiology',
#  'memory',
#  'episodic',
#  'reinforcement',
#  'psychology',
#  'reward',
#  'anoctamins genetics',
#  'cognitive',
#  'dysfunction physiopathology',
#  'disease',
#  'progression',
#  'potential',
#  'somatosensory physiology',
#  'executive',
#  'function physiology',
#  'gene',
#  'recessive',
#  'middle',
#  'mutation',
#  'pedigree',
#  'spinocerebellar',
#  'ataxia genetics physiopathology',
#  'disease',
#  'model',
#  'animal',
#  'dose response',
#  'relationship',
#  'drug',
#  'drug',
#  'resistance',
#  'gene',
#  'expression',
#  'regulation drug',
#  'effect',
#  'newborn',
#  'membrane',
#  'glycoprotein antagonist',
#  'inhibitor metabolism',
#  'phenobarbital administration',
#  'dosage pharmacology',
#  'protein tyrosine',
#  'kinase antagonist',
#  'inhibitor metabolism',
#  'seizure diagnosis drug',
#  'therapy etiology metabolism',
#  'symporters genetics metabolism',
#  'basal',
#  'ganglion physiopathology',
#  'beta',
#  'rhythm physiology',
#  'cerebral',
#  'cortex physiopathology',
#  'disease',
#  'model',
#  'animal',
#  'phase',
#  'synchronization physiology',
#  'gamma',
#  'rhythm physiology',
#  'nerve',
#  'net physiopathology',
#  'oxidopamine pharmacology',
#  'parkinsonian',
#  'disorder chemically',
#  'induced physiopathology',
#  'rat',
#  'rat',
#  'sprague dawley',
#  'subthalamic',
#  'nucleus physiopathology',
#  'calcium',
#  'channel genetics',
#  'cerebral',
#  'cortex physiopathology',
#  'disease',
#  'model',
#  'animal',
#  'electrocorticography',
#  'epilepsy',
#  'absence genetics physiopathology',
#  'mutant',
#  'strain',
#  'neuron physiology',
#  'neuropil physiology',
#  'seizure physiopathology',
#  'visual',
#  'cortex physiopathology',
#  'algorithm',
#  'brain anatomy',
#  'histology physiology',
#  'electrode',
#  'model',
#  'theoretical',
#  'brain physiopathology',
#  'brain computer',
#  'interface',
#  'consciousness',
#  'disorder diagnosis physiopathology',
#  'diagnosis',
#  'computer assisted method',
#  'potential',
#  'fixation',
#  'ocular physiology',
#  'middle',
#  'neurologic',
#  'examination',
#  'pilot',
#  'project',
#  'severity',
#  'illness',
#  'index',
#  'user computer',
#  'interface',
#  'brain physiopathology',
#  'ectodermal',
#  'dysplasia genetics physiopathology',
#  'epilepsy genetics physiopathology',
#  'guanine',
#  'nucleotide',
#  'exchange',
#  'factor genetics',
#  'limb',
#  'deformity',
#  'congenital genetics physiopathology',
#  'mutation',
#  'phenotype',
#  'scalp',
#  'dermatosis congenital genetics physiopathology',
#  'brain diagnostic',
#  'imaging physiopathology',
#  'abuse',
#  'cohort',
#  'study',
#  'craniocerebral',
#  'trauma complication diagnostic',
#  'imaging physiopathology therapy',
#  'critical',
#  'care',
#  'hypoxia ischemia',
#  'brain complication diagnostic',
#  'imaging physiopathology therapy',
#  'magnetic',
#  'resonance',
#  'imaging',
#  'retrospective',
#  'study',
#  'seizure complication diagnostic',
#  'imaging physiopathology therapy',
#  'severity',
#  'illness',
#  'index',
#  'brain physiopathology',
#  'brain',
#  'injury diagnosis etiology',
#  'extracorporeal',
#  'membrane',
#  'oxygenation',
#  'middle',
#  'prognosis',
#  'prospective',
#  'study',
#  'reflex',
#  'pupillary',
#  'shock',
#  'cardiogenic complication therapy',
#  'algorithm',
#  'brain computer',
#  'interface',
#  'electrooculography',
#  'robotics method',
#  'vision',
#  'ocular',
#  'anesthesia',
#  'general adverse',
#  'effect trend',
#  'anesthetic',
#  'inhalation administration',
#  'dosage adverse',
#  'effect',
#  'cerebral',
#  'cortex drug',
#  'effect physiology',
#  'consciousness',
#  'monitor standard',
#  'desflurane administration',
#  'dosage adverse',
#  'effect',
#  'middle',
#  'monitoring',
#  'intraoperative method standard',
#  'artifact',
#  'brain physiology',
#  'electroencephalography method standard',
#  'magnetic',
#  'resonance',
#  'imaging method standard',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity complication',
#  'attention',
#  'deficit',
#  'disruptive',
#  'behavior',
#  'disorder complication',
#  'brain',
#  'mapping',
#  'potential physiology',
#  'neuropsychological',
#  'test',
#  'personality',
#  'inventory',
#  'roc',
#  'curve',
#  'statistic',
#  'nonparametric',
#  'temperament physiology',
#  'brain physiopathology',
#  'potential genetics',
#  'photic',
#  'stimulation method',
#  'attention',
#  'deficit',
#  'disorder',
#  'hyperactivity diagnosis pathology',
#  'neurofeedback method',
#  'auditory',
#  'perception physiology',
#  'brain physiology',
#  'memory',
#  'short term physiology',
#  'neural',
#  'pathway physiology',
#  'visual',
#  'perception physiology',
#  'algorithm',
#  'automation',
#  'preschool',
#  'computing',
#  'methodology',
#  'database',
#  'factual',
#  'electroencephalography classification method',
#  'learning',
#  'reproducibility',
#  'result',
#  'seizure diagnosis',
#  'sensitivity',
#  'specificity',
#  'support',
#  'vector',
#  'machine',
#  'brain physiology',
#  'brain',
#  'chemistry',
#  'empathy',
#  'family',
#  'characteristic',
#  'hand physiology',
#  'interpersonal',
#  'relation',
#  'pain physiopathology psychology',
#  'pain',
#  'measurement',
#  'acute',
#  'disease',
#  'brain diagnostic',
#  'imaging physiopathology',
#  'brain',
#  'edema diagnostic',
#  'imaging physiopathology',
#  'preschool',
#  'fatal',
#  'outcome',
#  'hyponatremia diagnostic',
#  'imaging physiopathology',
#  'intracranial',
#  'pressure',
#  'seizure diagnostic',
#  'imaging physiopathology',
#  'academic',
#  'medical',
#  'center economics trend',
#  'drug',
#  'resistant',
#  'epilepsy economics surgery',
#  'health',
#  'service',
#  'accessibility economics trend',
#  'hospital',
#  'high volume trend',
#  'neurosurgical',
#  'procedure economics trend',
#  'public private',
#  'sector',
#  'partnership economics trend',
#  'anticonvulsant therapeutic',
#  'use',
#  'brain',
#  'mapping method',
#  'drug',
#  'resistance',
#  'electric',
#  'stimulation',
#  'epilepsy',
#  'partial diagnosis drug',
#  'therapy physiopathology psychology',
#  'potential',
#  'somatosensory',
#  'median',
#  'nerve physiopathology',
#  'somatosensory',
#  'cortex physiopathology',
#  'time',
#  'factor',
#  'touch',
#  'touch',
#  'perception',
#  'cognition physiology',
#  'potential physiology',
#  'middle',
#  'motivation physiology',
#  'reward',
#  'schizophrenia physiopathology',
#  '80',
#  'middle',
#  'polysomnography method',
#  'reproducibility',
#  'result',
#  'sleep physiology',
#  'sleep',
#  'apnea',
#  'obstructive diagnosis physiopathology',
#  'wakefulness physiology',
#  'classical',
#  'lissencephalies',
#  'subcortical',
#  'band',
#  'heterotopias physiopathology',
#  'disease',
#  'model',
#  'animal',
#  'electrocorticography method',
#  'microtubule associated',
#  'protein metabolism',
#  'rat',
#  'wistar',
#  'seizure complication physiopathology',
#  'wakefulness physiology',
#  'cognitive',
#  'behavioral',
#  'therapy method',
#  'couple',
#  'therapy method',
#  'dna',
#  'methylation',
#  'depression therapy',
#  'empathy',
#  'eye',
#  'movement',
#  'measurement',
#  'heart',
#  'rate',
#  'hydrocortisone metabolism',
#  'interleukin 1beta blood',
#  'interleukin 6 blood',
#  'interpersonal',
#  'relation',
#  'psychiatric',
#  'status',
#  'rating',
#  ...]

# %%
strlist2018 = str(docMesh2018)
strlist2019 = str(docMesh2019)
strlist2020 = str(docMesh2020)
docMesh2018 = [strlist2018]
docMesh2019 = [strlist2019]
docMesh2020 = [strlist2020]

# %%
for i in docMesh2018:
 docMesh2020.append(i)

# %%
for i in docMesh2019:
 docMesh2020.append(i)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(lowercase = False)
sparseMesh = tfidf.fit_transform(docMesh2020)

print("Tokens used as features are : ")
print(tfidf.get_feature_names())
tokens = tfidf.get_feature_names()
print("How many columns : ", len(tokens))

print("\n Size of array. Each row represents a document. Each column represents a feature/token")
print(sparseMesh.shape)

print("\n Actual TF-IDF array")
text1 = sparseMesh.toarray()
print(text1)
# Out:
# Tokens used as features are :
# ['10', '11', '12', '129', '13', '14', '15', '15th', '16', '16th', '17th', '18th', '19', '19th', '1beta', '20', '2001', '2003', '2011', '20th', '21', '21st', '22', '22q11', '25', '26', '3a', '3t3', '43', '450', '50', '80', 'a1', 'a2', 'a2a', 'abattoir', 'abdomen', 'abdominal', 'abducens', 'aberration', 'ablation', 'abnormal', 'abnormality', 'abrin', 'abscess', 'absence', 'absorbable', 'absorption', 'abstinence', 'abuse', 'academic', 'academy', 'acceleration', 'accelerometry', 'acceptance', 'acceptor', 'access', 'accessibility', 'accident', 'accidental', 'acclimatization', 'accommodation', 'accumbens', 'accuracy', 'acepromazine', 'acetaldehyde', 'acetamide', 'acetaminophen', 'acetate', 'acetazolamide', 'acetophenones', 'acetylation', 'acetylcholine', 'acetylcholinesterase', 'acetylcysteine', 'acetylglucosaminidase', 'acetyltransferase', 'acetyltransferases', 'achievement', 'achilles', 'aci', 'acid', 'acidemia', 'acidic', 'acidosis', 'aciduria', 'acoustic', 'acquired', 'actigraphy', 'actin', 'acting', 'action', 'activated', 'activating', 'activation', 'activator', 'activity', 'acuity', 'acupuncture', 'acute', 'acyclovir', 'acyl', 'acyltransferases', 'adam10', 'adapalene', 'adaptation', 'adaptor', 'addiction', 'addictive', 'addison', 'additive', 'adenine', 'adenoid', 'adenoma', 'adenomatous', 'adenosine', 'adenoviridae', 'adenovirus', 'adenylyl', 'adh', 'adherence', 'adhesion', 'adhesive', 'adipocytes', 'adipokines', 'adipose', 'adiposity', 'adjusted', 'adjustment', 'adjuvant', 'administration', 'administrative', 'admission', 'adoptive', 'adp', 'adrenal', 'adrenergic', 'adrenocorticotropic', 'adrenoleukodystrophy', 'adult', 'advance', 'advanced', 'advancement', 'adverse', 'advertising', 'advisory', 'aerosol', 'aerospace', 'aethiops', 'affair', 'affect', 'affective', 'afferent', 'afghan', 'afibrinogenemia', 'africa', 'african', 'aftercare', 'aftereffect', 'agalactiae', 'agar', 'age', 'aged', 'agency', 'agenesis', 'agent', 'aggrecans', 'aggregate', 'aggregation', 'aggression', 'aggressive', 'aging', 'agitation', 'agnosia', 'agonist', 'agoraphobia', 'agriculture', 'aicardi', 'aid', 'aided', 'air', 'aircraft', 'airway', 'akinetic', 'akt', 'alanine', 'alaryngeal', 'alaskan', 'alberta', 'albumin', 'albuterol', 'alcohol', 'alcoholic', 'alcoholism', 'aldehyde', 'aldosterone', 'alemtuzumab', 'algorithm', 'alice', 'alignment', 'alkaline', 'alkaloid', 'alkylating', 'alkyne', 'allele', 'allied', 'alligator', 'allocation', 'allopurinol', 'allosteric', 'alopecia', 'alpha', 'alpha7', 'alphavirus', 'alprazolam', 'alternative', 'altitude', 'altruism', 'aluminum', 'alveolus', 'alzheimer', 'amantadine', 'amblyopia', 'ambroxol', 'ambulance', 'ambulatory', 'america', 'american', 'americium', 'amide', 'amidines', 'amino', 'aminoadipic', 'aminobutyric', 'aminopyridine', 'aminopyridines', 'aminoquinolines', 'amitriptyline', 'ammonia', 'ammonium', 'amnesia', 'amnestic', 'amnion', 'amniotic', 'amobarbital', 'amp', 'ampa', 'amphetamine', 'amplified', 'amplifier', 'amputation', 'amputee', 'amygdala', 'amylase', 'amyloid', 'amyloidosis', 'amyotrophic', 'analgesia', 'analgesic', 'analog', 'analysis', 'analytical', 'anatomic', 'anatomy', 'ancestry', 'ancient', 'androgen', 'androstanols', 'anemia', 'anemone', 'anesthesia', 'anesthesiologist', 'anesthesiology', 'anesthetic', 'anesthetist', 'aneurysm', 'angelica', 'angelman', 'anger', 'angina', 'angiofibroma', 'angiography', 'angiopathy', 'angiotensin', 'angle', 'anhedonia', 'aniline', 'animal', 'anion', 'aniridia', 'anisotropy', 'ankle', 'ankylosing', 'annexin', 'anniversary', 'annotation', 'anoctamins', 'anomia', 'anorexia', 'antagomirs', 'antagonist', 'antelope', 'anterior', 'anterograde', 'anthocyanins', 'anthracyclines', 'anthropology', 'anthropometry', 'anti', 'antibiotic', 'antibody', 'antichymotrypsin', 'anticipation', 'anticoagulant', 'anticonvulsant', 'antidepressive', 'antidote', 'antiemetic', 'antigen', 'antihypertensive', 'antimanic', 'antimetabolite', 'antimitotic', 'antineoplastic', 'antinuclear', ' ...
# How many columns :  5450
#
#  Size of array. Each row represents a document. Each column represents a feature/token
# (3, 5450)
#
#  Actual TF-IDF array
# [[0.00000000e+00 0.00000000e+00 2.63909229e-04 ... 0.00000000e+00
#   0.00000000e+00 1.31954614e-04]
#  [0.00000000e+00 9.76439234e-05 5.76700741e-05 ... 7.42607206e-05
#   1.95287847e-04 5.76700741e-05]
#  [1.02966760e-04 0.00000000e+00 3.64882965e-04 ... 1.56617751e-04
#   0.00000000e+00 6.08138274e-05]]

# %%
resultat = pd.DataFrame(sparseMesh[0].T.todense(), index = tokens, columns=["TF-IDF"])
resultat = resultat.loc[(resultat != 0).all(axis=1), :]
resultat = resultat.sort_values('TF-IDF', ascending=False)
print (resultat.head(10))
# Out:
#                    TF-IDF
# physiology       0.710576
# physiopathology  0.327115
# brain            0.234351
# method           0.188431
# imaging          0.150032
# diagnosis        0.149505
# drug             0.145414
# diagnostic       0.118099
# therapy          0.105564
# potential        0.102529

# %%
resultat = pd.DataFrame(sparseMesh[2].T.todense(), index = tokens, columns=["TF-IDF"])
resultat = resultat.loc[(resultat != 0).all(axis=1), :]
resultat = resultat.sort_values('TF-IDF', ascending=False)
print (resultat.head(10))
# Out:
#                    TF-IDF
# physiology       0.777444
# physiopathology  0.304373
# brain            0.211632
# method           0.166022
# drug             0.119378
# diagnosis        0.118465
# imaging          0.117918
# potential        0.110255
# effect           0.089153
# middle           0.088484

# %%
resultat = pd.DataFrame(sparseMesh[1].T.todense(), index = tokens, columns=["TF-IDF"])
resultat = resultat.loc[(resultat != 0).all(axis=1), :]
resultat = resultat.sort_values('TF-IDF', ascending=False)
print (resultat.head(10))
# Out:
#                    TF-IDF
# physiology       0.771337
# physiopathology  0.292214
# brain            0.228200
# method           0.163495
# imaging          0.132757
# drug             0.123818
# potential        0.116205
# diagnosis        0.113091
# diagnostic       0.099250
# effect           0.093945
